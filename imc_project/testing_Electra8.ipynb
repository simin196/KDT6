# %%
import json
import numpy as np
import torch
from torch.utils.data import DataLoader, Dataset
from transformers import AutoTokenizer, AutoModelForTokenClassification
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from torch.nn.utils.rnn import pad_sequence
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
# 토크나이저와 모델
model = AutoModelForTokenClassification.from_pretrained('./koelectra_v3_ner_model5')
tokenizer = AutoTokenizer.from_pretrained('./koelectra_v3_ner_model5')
file_path = './data/test/test_data_all.json'

# %%
# data 불러오기
def load_data(file_path):
    """JSON 파일에서 NER 데이터 로드"""
    with open(file_path, 'r', encoding='utf-8') as file:
        return json.load(file)

# %%
# KoNERDataset전용 클래스 생성
class KoNERDataset(Dataset):
    
    def __init__(self, encodings, labels):
        self.encodings = encodings
        self.labels = labels

    def __getitem__(self, idx):
        item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
        item['labels'] = torch.tensor(self.labels[idx])
        return item
    
    def __len__(self):
        return len(self.labels)

# %%
def prepare_koelectra_ner_data(data, tokenizer, max_length=64):
   
    """KoElectra용 NER 데이터 준비"""

    # text = []
    tokens = [d['tokens'] for d in data]
    labels = [d['ner_tags'] for d in data]

    # tokens

    # KoElectra 토크나이저로 인코딩
    encodings = tokenizer(
        tokens, 
        is_split_into_words=True, 
        padding=True, 
        truncation=True, 
        max_length=max_length,
        return_tensors='pt'
    )

    # NER 라벨 처리
    new_labels = []
    for i, label in enumerate(labels):
        word_ids = encodings.word_ids(batch_index=i)
        label_ids = [-100] * len(word_ids)  # 초기값 -100으로 설정
        
        # 개선된 라벨 매핑 로직
        for word_idx, tag in enumerate(label):
            # word_ids에서 해당 word_idx의 첫 번째 인덱스 찾기
            indices = [j for j, w_id in enumerate(word_ids) if w_id == word_idx]
            
            if indices:
                # 첫 번째 인덱스에 태그 할당
                label_ids[indices[0]] = tag
        
        new_labels.append(label_ids)

    return encodings, new_labels

# %%
def test_koelectra_ner_model(model, test_dataset, test_data):
    """모델 테스트"""
    model.to(device)
    model.eval()

    all_test_data = []
    all_preds = []
    all_labels = []
    all_tokens = []  # 원본 토큰 저장용
    for a in test_data:
        all_test_data.append(a['tokens'])
    
    with torch.no_grad():
        for batch in test_dataset:
            input_ids = batch['input_ids'].to(device)
            attention_mask = batch['attention_mask'].to(device)
            labels = batch['labels']

            outputs = model(
                input_ids, 
                attention_mask=attention_mask
            )
            
            predictions = torch.argmax(outputs.logits, dim=-1)
        

            # 유효한 예측과 레이블만 수집
            for pred, label, input_id in zip(predictions, labels, input_ids):
                mask = label != -100
                all_preds.extend(pred[mask].cpu().numpy())
                all_labels.extend(label[mask].numpy())
                 
                # 토큰 디코딩 (원본 토큰 복원)
                tokens = tokenizer.convert_ids_to_tokens(input_id)
                all_tokens.extend([token for token, m in zip(tokens, mask) if m])       
    
    # 상세 분류 보고서 출력
    print("Classification Report:")
    print(classification_report(all_labels, all_preds))

    # 일부 잘못 예측된 케이스 출력 (선택사항)
    print("\n일부 잘못 예측된 예시:")
    for token, true_label, pred_label in zip(all_tokens, all_labels, all_preds):
        if true_label != pred_label:
            print(f"Token: {token}, True Label: {true_label}, Predicted Label: {pred_label}")

# %%
test_file_path = './data/test/test_data_all.json'

def main_test():

    model= AutoModelForTokenClassification.from_pretrained('./koelectra_v3_ner_model5')

    # 테스트 데이터 로드 
    test_data = load_data(test_file_path)

    # 테스트 데이터 준비
    test_encodings, test_labels = prepare_koelectra_ner_data(test_data, tokenizer)

    # 테스트 데이터셋 생성
    test_dataset = DataLoader(
        KoNERDataset(test_encodings, test_labels), 
        batch_size=8, 
        shuffle=False
    )

    # 모델 테스트
    test_koelectra_ner_model(model, test_dataset, test_data)

if __name__ == '__main__':
    main_test()
# Out:
# C:\Users\KDP-23\AppData\Local\Temp\ipykernel_13056\4259181314.py:9: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.90      0.96      0.93       578
#            1       0.96      0.93      0.94        82
#            2       0.92      0.93      0.92       389
#            3       0.85      0.88      0.87       165
#            4       0.93      0.89      0.91       854
#            5       0.94      0.95      0.95       152
#            6       0.96      0.94      0.95       174
#
#     accuracy                           0.92      2394
#    macro avg       0.92      0.92      0.92      2394
# weighted avg       0.92      0.92      0.92      2394
#
#
# 일부 잘못 예측된 예시:
# Token: 도, True Label: 4, Predicted Label: 0
# Token: 담, True Label: 3, Predicted Label: 2
# Token: 백, True Label: 4, Predicted Label: 3
# Token: 아, True Label: 3, Predicted Label: 0
# Token: 이, True Label: 4, Predicted Label: 0
# Token: 아, True Label: 4, Predicted Label: 0
# Token: 또, True Label: 4, Predicted Label: 0
# Token: 마, True Label: 4, Predicted Label: 6
# Token: 리, True Label: 4, Predicted Label: 0
# Token: 세, True Label: 4, Predicted Label: 0
# Token: 트, True Label: 4, Predicted Label: 0
# Token: 딸, True Label: 3, Predicted Label: 0
# Token: 기, True Label: 4, Predicted Label: 0
# Token: 케, True Label: 4, Predicted Label: 0
# Token: 추, True Label: 4, Predicted Label: 0
# Token: 계, True Label: 4, Predicted Label: 0
# Token: 란, True Label: 4, Predicted Label: 0
# Token: 물, True Label: 4, Predicted Label: 3
# Token: 김, True Label: 6, Predicted Label: 3
# Token: 치, True Label: 6, Predicted Label: 4
# Token: 만, True Label: 3, Predicted Label: 4
# Token: 두, True Label: 5, Predicted Label: 4
# Token: 하, True Label: 6, Predicted Label: 5
# Token: 칼, True Label: 3, Predicted Label: 4
# Token: 닭, True Label: 3, Predicted Label: 2
# Token: 갈, True Label: 4, Predicted Label: 2
# Token: 비, True Label: 4, Predicted Label: 2
# Token: 분, True Label: 6, Predicted Label: 0
# Token: 치, True Label: 4, Predicted Label: 0
# Token: 즈, True Label: 4, Predicted Label: 0
# Token: 세, True Label: 4, Predicted Label: 0
# Token: 세, True Label: 4, Predicted Label: 0
# Token: 트, True Label: 4, Predicted Label: 0
# Token: 도, True Label: 4, Predicted Label: 0
# Token: 시, True Label: 4, Predicted Label: 3
# Token: 파, True Label: 4, Predicted Label: 1
# Token: 스, True Label: 4, Predicted Label: 2
# Token: 타, True Label: 4, Predicted Label: 2
# Token: 석, True Label: 3, Predicted Label: 0
# Token: 류, True Label: 4, Predicted Label: 3
# Token: 카, True Label: 4, Predicted Label: 2
# Token: 레, True Label: 4, Predicted Label: 2
# Token: 2, True Label: 5, Predicted Label: 0
# Token: 도, True Label: 3, Predicted Label: 0
# Token: 련, True Label: 4, Predicted Label: 0
# Token: 님, True Label: 4, Predicted Label: 0
# Token: 도, True Label: 4, Predicted Label: 0
# Token: 시, True Label: 4, Predicted Label: 3
# Token: 1, True Label: 5, Predicted Label: 0
# Token: 5, True Label: 6, Predicted Label: 0
# Token: 개, True Label: 6, Predicted Label: 0
# Token: 마, True Label: 3, Predicted Label: 2
# Token: 라, True Label: 4, Predicted Label: 2
# Token: 탕, True Label: 4, Predicted Label: 2
# Token: 분, True Label: 6, Predicted Label: 0
# Token: 꿔, True Label: 3, Predicted Label: 0
# Token: 바, True Label: 4, Predicted Label: 0
# Token: 로, True Label: 4, Predicted Label: 0
# Token: 여, True Label: 5, Predicted Label: 4
# Token: 섯, True Label: 6, Predicted Label: 4
# Token: 팟, True Label: 3, Predicted Label: 4
# Token: 제, True Label: 4, Predicted Label: 3
# Token: 선, True Label: 3, Predicted Label: 0
# Token: 지, True Label: 4, Predicted Label: 3
# Token: 보, True Label: 0, Predicted Label: 4
# Token: 통, True Label: 0, Predicted Label: 4
# Token: 맛, True Label: 0, Predicted Label: 4
# Token: 쭈, True Label: 3, Predicted Label: 0
# Token: 한, True Label: 5, Predicted Label: 4
# Token: 미, True Label: 6, Predicted Label: 0
# Token: 도, True Label: 4, Predicted Label: 0
# Token: 시, True Label: 4, Predicted Label: 3
# Token: 콜, True Label: 0, Predicted Label: 3
# Token: 라, True Label: 0, Predicted Label: 4
# Token: 1, True Label: 4, Predicted Label: 5
# Token: 개, True Label: 5, Predicted Label: 6
# Token: 랑, True Label: 6, Predicted Label: 0
# Token: 참, True Label: 0, Predicted Label: 3
# Token: 치, True Label: 3, Predicted Label: 4
# Token: 1, True Label: 4, Predicted Label: 5
# Token: 개, True Label: 5, Predicted Label: 6
# Token: 랑, True Label: 6, Predicted Label: 0
# Token: 계, True Label: 0, Predicted Label: 3
# Token: 란, True Label: 0, Predicted Label: 4
# Token: 유, True Label: 0, Predicted Label: 4
# Token: 부, True Label: 0, Predicted Label: 4
# Token: 초, True Label: 0, Predicted Label: 4
# Token: 밥, True Label: 0, Predicted Label: 4
# Token: 2, True Label: 0, Predicted Label: 5
# Token: 개, True Label: 0, Predicted Label: 6
# Token: 구, True Label: 0, Predicted Label: 3
# Token: 운, True Label: 0, Predicted Label: 4
# Token: 연, True Label: 0, Predicted Label: 4
# Token: 어, True Label: 0, Predicted Label: 4
# Token: 유, True Label: 0, Predicted Label: 4
# Token: 부, True Label: 0, Predicted Label: 4
# Token: 초, True Label: 0, Predicted Label: 4
# Token: 밥, True Label: 0, Predicted Label: 4
# Token: 2, True Label: 0, Predicted Label: 5
# Token: 개, True Label: 0, Predicted Label: 6
# Token: 맛, True Label: 4, Predicted Label: 0
# Token: 짜, True Label: 4, Predicted Label: 3
# Token: 물, True Label: 4, Predicted Label: 2
# Token: 냉, True Label: 4, Predicted Label: 2
# Token: 면, True Label: 4, Predicted Label: 2
# Token: 백, True Label: 1, Predicted Label: 2
# Token: 불, True Label: 3, Predicted Label: 1
# Token: 맛, True Label: 4, Predicted Label: 2
# Token: 제, True Label: 4, Predicted Label: 2
# Token: 육, True Label: 4, Predicted Label: 2
# Token: 뽁, True Label: 4, Predicted Label: 2
# Token: 밥, True Label: 4, Predicted Label: 2
# Token: 뽁, True Label: 1, Predicted Label: 2
# Token: 세, True Label: 4, Predicted Label: 0
# Token: 트, True Label: 4, Predicted Label: 0
# Token: 나, True Label: 3, Predicted Label: 0
# Token: 홀, True Label: 4, Predicted Label: 0
# Token: 로, True Label: 4, Predicted Label: 0
# Token: 국, True Label: 4, Predicted Label: 3
# Token: 가, True Label: 4, Predicted Label: 0
# Token: 쓰, True Label: 4, Predicted Label: 0
# Token: 오, True Label: 4, Predicted Label: 3
# Token: 삼, True Label: 4, Predicted Label: 2
# Token: 겹, True Label: 4, Predicted Label: 2
# Token: 짜, True Label: 4, Predicted Label: 2
# Token: 글, True Label: 4, Predicted Label: 2
# Token: 이, True Label: 4, Predicted Label: 2
# Token: 짜, True Label: 1, Predicted Label: 2
# Token: 세, True Label: 4, Predicted Label: 0
# Token: 트, True Label: 4, Predicted Label: 0
# Token: 치, True Label: 4, Predicted Label: 1
# Token: 밥, True Label: 4, Predicted Label: 2
# Token: 도, True Label: 4, Predicted Label: 0
# Token: 뉴, True Label: 0, Predicted Label: 4
# Token: 짬, True Label: 4, Predicted Label: 3
# Token: 볶, True Label: 4, Predicted Label: 3
# Token: 물, True Label: 4, Predicted Label: 3
# Token: 바, True Label: 4, Predicted Label: 2
# Token: 베, True Label: 4, Predicted Label: 2
# Token: 큐, True Label: 4, Predicted Label: 2
# Token: 치, True Label: 4, Predicted Label: 2
# Token: 킨, True Label: 4, Predicted Label: 2
# Token: 고, True Label: 3, Predicted Label: 0
# Token: 구, True Label: 4, Predicted Label: 3
# Token: 해, True Label: 2, Predicted Label: 4
# Token: 장, True Label: 2, Predicted Label: 4
# Token: 국, True Label: 2, Predicted Label: 4
# Token: 버, True Label: 1, Predicted Label: 4
# Token: 거, True Label: 2, Predicted Label: 4
# Token: 운, True Label: 2, Predicted Label: 4
# Token: 그, True Label: 4, Predicted Label: 0
# Token: 버, True Label: 2, Predicted Label: 4
# Token: 거, True Label: 2, Predicted Label: 4
# Token: 양, True Label: 4, Predicted Label: 3
# Token: 지, True Label: 1, Predicted Label: 3
# Token: 코, True Label: 2, Predicted Label: 4
# Token: 곱, True Label: 2, Predicted Label: 4
# Token: 창, True Label: 2, Predicted Label: 4
# Token: 제, True Label: 4, Predicted Label: 3
# Token: 서, True Label: 3, Predicted Label: 0
# Token: 리, True Label: 4, Predicted Label: 3
# Token: 망, True Label: 3, Predicted Label: 0
# Token: 고, True Label: 4, Predicted Label: 0
# Token: 요, True Label: 4, Predicted Label: 0
# Token: 거, True Label: 4, Predicted Label: 0
# Token: 트, True Label: 4, Predicted Label: 0
# Token: 하, True Label: 4, Predicted Label: 5
# Token: 나, True Label: 4, Predicted Label: 6
# Token: 하, True Label: 4, Predicted Label: 5
# Token: 나, True Label: 4, Predicted Label: 6
# Token: 버, True Label: 2, Predicted Label: 4
# Token: 거, True Label: 2, Predicted Label: 4
# Token: 버, True Label: 2, Predicted Label: 4
# Token: 거, True Label: 2, Predicted Label: 4
# Token: 삼, True Label: 2, Predicted Label: 4
# Token: 계, True Label: 2, Predicted Label: 4
# Token: 탕, True Label: 2, Predicted Label: 4
# Token: 석, True Label: 1, Predicted Label: 3
# Token: 봉, True Label: 2, Predicted Label: 4
# Token: 토, True Label: 2, Predicted Label: 4
# Token: 스, True Label: 2, Predicted Label: 4
# Token: 트, True Label: 2, Predicted Label: 4
# Token: 토, True Label: 2, Predicted Label: 4
# Token: 스, True Label: 2, Predicted Label: 4
# Token: 트, True Label: 2, Predicted Label: 4
# Token: 토, True Label: 2, Predicted Label: 4
# Token: 스, True Label: 2, Predicted Label: 4
# Token: 트, True Label: 2, Predicted Label: 4
# Token: 하, True Label: 4, Predicted Label: 5
# Token: 생, True Label: 4, Predicted Label: 0
# Token: 3, True Label: 4, Predicted Label: 5
# Token: 트, True Label: 0, Predicted Label: 4
# Token: 시, True Label: 4, Predicted Label: 0
# Token: 즈, True Label: 4, Predicted Label: 0

# %% [markdown]
# - - -

# %%
import os
import json

# %%
# 파일 읽기
try:
    with open('./test_Data_tag.json', 'r', encoding='utf-8') as file:
        ner_all = json.load(file)
except FileNotFoundError:
    raise Exception("파일을 찾을 수 없습니다. 경로를 확인하세요.")
except json.JSONDecodeError:
    raise Exception("JSON 파일이 잘못된 형식입니다.")

# %%
ner_all
# Out:
# [{'tokens': ['치',
#    '밥',
#    '의',
#    '달인',
#    '에서',
#    '불향',
#    '바베큐',
#    '치',
#    '밥도시락',
#    '3',
#    '개',
#    ',',
#    '담백',
#    '한',
#    '숯불',
#    '간장',
#    '치',
#    '밥',
#    '2',
#    '개',
#    '주문',
#    '할',
#    '게'],
#   'ner_tags': [1,
#    2,
#    2,
#    2,
#    0,
#    3,
#    4,
#    4,
#    4,
#    5,
#    6,
#    0,
#    3,
#    4,
#    4,
#    4,
#    4,
#    4,
#    5,
#    6,
#    0,
#    0,
#    0]},
#  {'tokens': ['중',
#    '화루',
#    '에서',
#    '깐풍기',
#    '소자',
#    '하나',
#    '랑',
#    '나',
#    '홀로',
#    '세트',
#    'b',
#    '번',
#    '두',
#    '개',
#    ',',
#    '야',
#    '끼',
#    '우동',
#    '세',
#    '개',
#    '주문',
#    '할게요'],
#   'ner_tags': [1,
#    2,
#    0,
#    3,
#    4,
#    5,
#    0,
#    3,
#    4,
#    4,
#    4,
#    4,
#    5,
#    6,
#    0,
#    3,
#    4,
#    4,
#    5,
#    6,
#    0,
#    0]},
#  {'tokens': ['카페베네',
#    '에서',
#    '허니',
#    '브레드',
#    '두',
#    '개',
#    '아이스',
#    '아메리카노',
#    '3',
#    '잔',
#    '카라멜',
#    '마',
#    '끼',
#    '아',
#    '또',
#    '두',
#    '잔',
#    '주세요'],
#   'ner_tags': [1, 0, 3, 4, 5, 6, 3, 4, 5, 6, 3, 4, 4, 4, 4, 5, 6, 0]},
#  {'tokens': ['호식',
#    '이',
#    '두',
#    '마리',
#    '치킨',
#    '에서',
#    '후라이드',
#    '간장',
#    '두',
#    '마리',
#    '세트',
#    '두',
#    '개',
#    '씩',
#    '주문',
#    '해',
#    '줘'],
#   'ner_tags': [1, 2, 2, 2, 2, 0, 3, 4, 4, 4, 4, 5, 6, 6, 0, 0, 0]},
#  {'tokens': ['고운',
#    '라멘',
#    '에서',
#    '기본',
#    '라멘',
#    '세',
#    '개',
#    '바질',
#    '라멘',
#    '2',
#    '개',
#    '사이드',
#    '로',
#    '치킨',
#    '가라아게',
#    '5',
#    '개',
#    '주문',
#    '해',
#    '줘'],
#   'ner_tags': [1, 2, 0, 3, 4, 5, 6, 3, 4, 5, 6, 0, 0, 3, 4, 5, 6, 0, 0, 0]},
#  {'tokens': ['스타',
#    '벅스',
#    '에서',
#    '자바',
#    '초코',
#    '칩',
#    '프',
#    '라푸',
#    '치노',
#    '휘핑크림',
#    '올려서',
#    '한잔',
#    ',',
#    '딸기',
#    '케이크',
#    '한',
#    '개',
#    '주문',
#    '해',
#    '줘'],
#   'ner_tags': [1, 2, 0, 3, 4, 4, 4, 4, 4, 0, 0, 5, 0, 3, 4, 5, 6, 0, 0, 0]},
#  {'tokens': ['명가',
#    '우육',
#    '면',
#    '에서',
#    '마라',
#    '우육',
#    '면',
#    '2',
#    '개',
#    '주문',
#    '해',
#    '주',
#    '고',
#    '부추',
#    '계란',
#    '물만두',
#    '한',
#    '개',
#    '추가',
#    '해',
#    '줘'],
#   'ner_tags': [1, 2, 2, 0, 3, 4, 4, 5, 6, 0, 0, 0, 0, 3, 4, 4, 5, 6, 0, 0, 0]},
#  {'tokens': ['미들',
#    '31',
#    '에서',
#    '목살',
#    '플레이트',
#    '한',
#    '개',
#    ',',
#    '쉬',
#    '림프',
#    '로',
#    '제',
#    '파스타',
#    '한',
#    '개',
#    ',',
#    '타이',
#    '치킨',
#    '덮밥',
#    '한',
#    '개',
#    ',',
#    '우',
#    '삼',
#    '겹',
#    '오',
#    '일',
#    '파스타',
#    '한',
#    '개',
#    '주문',
#    '해',
#    '줘'],
#   'ner_tags': [1,
#    2,
#    0,
#    3,
#    4,
#    5,
#    6,
#    0,
#    3,
#    4,
#    4,
#    4,
#    4,
#    5,
#    6,
#    0,
#    3,
#    4,
#    4,
#    5,
#    6,
#    0,
#    3,
#    4,
#    4,
#    4,
#    4,
#    4,
#    5,
#    6,
#    0,
#    0,
#    0]},
#  {'tokens': ['현풍',
#    '닭',
#    '칼국수',
#    '에서',
#    '닭',
#    '칼국수',
#    '3',
#    '개',
#    '랑',
#    '고기만두',
#    '하나',
#    '김치',
#    '만',
#    '두',
#    '하나',
#    '주문',
#    '해',
#    '줘'],
#   'ner_tags': [1, 2, 2, 0, 3, 4, 5, 6, 0, 3, 5, 6, 3, 5, 6, 0, 0, 0]},
#  {'tokens': ['한식',
#    '에',
#    '빠지',
#    '다',
#    '에서',
#    '스팸',
#    '김치찌개',
#    '정식',
#    '2',
#    '개',
#    '닭갈비',
#    '덮밥',
#    '1',
#    '개',
#    '돼지갈비',
#    '덮밥',
#    '1',
#    '개',
#    '주문',
#    '할게요'],
#   'ner_tags': [1, 2, 2, 2, 0, 3, 4, 4, 5, 6, 3, 4, 5, 6, 3, 4, 5, 6, 0, 0]},
#  {'tokens': ['큰',
#    '바우',
#    '국밥',
#    '에서',
#    '돼지국밥',
#    '2',
#    '그릇',
#    '찰',
#    '순대',
#    '국밥',
#    '2',
#    '그릇',
#    '속풀이',
#    '국밥',
#    '한',
#    '그릇',
#    '가져다',
#    '줘'],
#   'ner_tags': [1, 2, 2, 0, 3, 5, 6, 3, 4, 4, 5, 6, 3, 4, 5, 6, 0, 0]},
#  {'tokens': ['김밥',
#    '천국',
#    '에서',
#    '원조',
#    '김밥',
#    '3',
#    '개',
#    '참치',
#    '김밥',
#    '3',
#    '개',
#    '라면',
#    '두',
#    '개',
#    '우동',
#    '두',
#    '개',
#    '돈',
#    '까스',
#    '하나',
#    '주',
#    '세요'],
#   'ner_tags': [1,
#    2,
#    0,
#    3,
#    4,
#    5,
#    6,
#    3,
#    4,
#    5,
#    6,
#    3,
#    5,
#    6,
#    3,
#    5,
#    6,
#    3,
#    4,
#    5,
#    0,
#    0]},
#  {'tokens': ['반반',
#    '한',
#    '찌개',
#    '한상',
#    '에서',
#    '우',
#    '삼',
#    '겹',
#    '된장찌개',
#    '2',
#    '개',
#    '순',
#    '살',
#    '닭도리탕',
#    '하나',
#    '청국장찌개',
#    '3',
#    '개',
#    '줘'],
#   'ner_tags': [1, 2, 2, 2, 0, 3, 4, 4, 4, 5, 6, 3, 4, 4, 5, 3, 5, 6, 0]},
#  {'tokens': ['준',
#    '삼',
#    '겹',
#    '프리미엄',
#    '에서',
#    '벌집',
#    '삼겹살',
#    '4',
#    '인분',
#    '칼집',
#    '목살',
#    '3',
#    '인분',
#    '볶',
#    '은',
#    '김치',
#    '하나',
#    '주문',
#    '해',
#    '줘'],
#   'ner_tags': [1, 2, 2, 2, 0, 3, 4, 5, 6, 3, 4, 5, 6, 3, 4, 4, 5, 0, 0, 0]},
#  {'tokens': ['유가',
#    '네',
#    '닭갈비',
#    '에서',
#    '닭갈비',
#    '4',
#    '인분',
#    '에',
#    '모',
#    '짜',
#    '렐라',
#    '치즈',
#    '추가',
#    '에',
#    '우동',
#    '사리',
#    '하나',
#    '추가',
#    '해',
#    '줘'],
#   'ner_tags': [1, 2, 2, 0, 3, 5, 6, 0, 3, 4, 4, 4, 0, 0, 3, 4, 5, 0, 0, 0]},
#  {'tokens': ['땅',
#    '스',
#    '부대찌개',
#    '에서',
#    '오리지널',
#    '부대찌개',
#    '3',
#    '인분',
#    '에',
#    '모둠',
#    '햄',
#    ',',
#    '라면',
#    '사리',
#    '두',
#    '개',
#    '추가',
#    '해',
#    '줘'],
#   'ner_tags': [1, 2, 2, 0, 3, 4, 5, 6, 0, 3, 4, 0, 3, 4, 5, 6, 0, 0, 0]},
#  {'tokens': ['대패',
#    '가',
#    '1900',
#    '에서',
#    '대패',
#    '삼',
#    '겹',
#    '고기',
#    '만',
#    '세트',
#    '대',
#    '자',
#    '하나',
#    '모던',
#    '대패',
#    '삼',
#    '겹',
#    '반반',
#    '세트',
#    '도시락',
#    '중자',
#    '하나',
#    '주',
#    '세요'],
#   'ner_tags': [1,
#    2,
#    2,
#    0,
#    3,
#    4,
#    4,
#    4,
#    4,
#    4,
#    4,
#    4,
#    5,
#    3,
#    4,
#    4,
#    4,
#    4,
#    4,
#    4,
#    4,
#    5,
#    0,
#    0]},
#  {'tokens': ['파스타',
#    '보이',
#    '에서',
#    '목살',
#    '필라프',
#    '1',
#    '개',
#    '베이컨',
#    '까르보',
#    '나라',
#    '두',
#    '개',
#    '쉬',
#    '림프',
#    '투',
#    '움',
#    '바',
#    '파스타',
#    '2',
#    '개',
#    '망고',
#    '에이드',
#    '3',
#    '잔',
#    '석류',
#    '에이드',
#    '3',
#    '잔',
#    '주문',
#    '할게요'],
#   'ner_tags': [1,
#    2,
#    0,
#    3,
#    4,
#    5,
#    6,
#    3,
#    4,
#    4,
#    5,
#    6,
#    3,
#    4,
#    4,
#    4,
#    4,
#    4,
#    5,
#    6,
#    3,
#    4,
#    5,
#    6,
#    3,
#    4,
#    5,
#    6,
#    0,
#    0]},
#  {'tokens': ['코레',
#    '와',
#    '카레',
#    '에서',
#    '안심',
#    '돈',
#    '카츠',
#    '카레',
#    '하나',
#    ',',
#    '모',
#    '짜',
#    '렐라',
#    '치즈',
#    '카츠',
#    '하나',
#    '주',
#    '세요'],
#   'ner_tags': [1, 2, 2, 0, 3, 4, 4, 4, 5, 0, 3, 4, 4, 4, 4, 5, 0, 0]},
#  {'tokens': ['한',
#    '솥',
#    '에서',
#    '빅',
#    '치킨',
#    '마요',
#    '20',
#    '개',
#    '도련님',
#    '돈',
#    '까스',
#    '도시락',
#    '15',
#    '개',
#    '주문',
#    '할게요'],
#   'ner_tags': [1, 2, 0, 3, 4, 4, 5, 6, 3, 4, 4, 4, 5, 6, 0, 0]},
#  {'tokens': ['둥근',
#    '이',
#    '숯불',
#    '두',
#    '마리',
#    '치킨',
#    '에서',
#    '우동',
#    '순',
#    '살',
#    '숯불',
#    '구',
#    '이',
#    '두',
#    '마리',
#    '숯불',
#    '라',
#    '갈비',
#    '치킨',
#    '한',
#    '마리',
#    '주세요'],
#   'ner_tags': [1,
#    2,
#    2,
#    2,
#    2,
#    2,
#    0,
#    3,
#    4,
#    4,
#    4,
#    4,
#    4,
#    5,
#    6,
#    3,
#    4,
#    4,
#    4,
#    5,
#    6,
#    0]},
#  {'tokens': ['구들',
#    '마라',
#    '탕',
#    '에서',
#    '마라',
#    '탕',
#    '2',
#    '인분',
#    '에',
#    '분모',
#    '자',
#    '추가',
#    '에',
#    '꿔',
#    '바로우',
#    '대',
#    '자',
#    '하나',
#    '주',
#    '세요'],
#   'ner_tags': [1, 2, 2, 0, 3, 4, 5, 6, 0, 3, 4, 0, 0, 3, 4, 4, 4, 5, 0, 0]},
#  {'tokens': ['신',
#    '짬뽕',
#    '국밥',
#    '에서',
#    '고기',
#    '짬뽕',
#    '국밥',
#    '2',
#    '개',
#    '순두부',
#    '짬뽕',
#    '국밥',
#    '1',
#    '개',
#    '고기',
#    '순대',
#    '2',
#    '개',
#    '주세요'],
#   'ner_tags': [1, 2, 2, 0, 3, 4, 4, 5, 6, 3, 4, 4, 5, 6, 3, 4, 5, 6, 0]},
#  {'tokens': ['호랑이',
#    '쌀국수',
#    '에서',
#    '차돌',
#    '양지',
#    '쌀국수',
#    '여섯',
#    '개',
#    '팟타이',
#    '네',
#    '개',
#    '새우',
#    '볼',
#    '3',
#    '개',
#    '추가',
#    '해',
#    '주',
#    '세요'],
#   'ner_tags': [1, 2, 0, 3, 4, 4, 5, 6, 3, 5, 6, 3, 4, 5, 6, 0, 0, 0, 0]},
#  {'tokens': ['신전',
#    '떡볶이',
#    '에서',
#    '신전',
#    '떡볶이',
#    '하나',
#    '마라',
#    '로',
#    '제',
#    '떡볶이',
#    '두',
#    '개',
#    '에',
#    '튀김',
#    '오뎅',
#    '4',
#    '개',
#    '튀김',
#    '만',
#    '두',
#    '3',
#    '개',
#    '김',
#    '말',
#    '이',
#    '5',
#    '개',
#    '주세요'],
#   'ner_tags': [1,
#    2,
#    0,
#    3,
#    4,
#    5,
#    3,
#    4,
#    4,
#    4,
#    5,
#    6,
#    0,
#    3,
#    4,
#    5,
#    6,
#    3,
#    4,
#    4,
#    5,
#    6,
#    3,
#    4,
#    4,
#    5,
#    6,
#    0]}]

# %%
# 변환된 데이터 저장
processed_data = []

for entry in ner_all:
    text = "".join(entry["tokens"])  # 토큰을 결합하여 원문 생성
    tokens = []  # 새롭게 쪼갠 토큰
    ner_tags = []  # 새롭게 매핑된 NER 태그

    for token, tag in zip(entry["tokens"], entry["ner_tags"]):
        if len(token) == 1:
            tokens.append(token)
            ner_tags.append(tag)
        else:
            # 한 글자씩 분리
            for i, char in enumerate(token):
                tokens.append(char)
                # 첫 번째 글자는 1, 3, 5 태그, 나머지는 2, 4, 6 태그
                if tag in [1, 3, 5]:
                    ner_tags.append(tag if i == 0 else tag + 1)
                else:
                    ner_tags.append(tag)

    # 새 포맷으로 저장
    processed_data.append({
        "tokens": tokens,
        "ner_tags": ner_tags
    })

# %%
# 파일 저장
for i in range(len(processed_data)):
    with open("test_data.json", "a", encoding="utf-8") as f:
        f.write(f'''
{{
"tokens" : {str(processed_data[i]["tokens"]).replace("'",'"')},
"ner_tags" : {processed_data[i]["ner_tags"]}
}},''')

print('파일 저장 완료')
# Out:
# 파일 저장 완료

# %% [markdown]
# ------------------------------------

# %%
### 파일 추가
# >> 기존에 있는 파일을 열어서 > 열었더

# 기존 파일 열기
# with open('./mecab/ner_all.json', 'r', encoding='utf-8') as file:
#     ner_all = json.load(file)

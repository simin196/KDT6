# %%
import pymysql
import pandas as pd
import matplotlib.pyplot as plt
import csv
import koreanize_matplotlib

# %%
conn = pymysql.connect(host='172.20.97.217', user='member3', password='1234', db = 'product', charset='utf8')
cur	= conn.cursor(pymysql.cursors.DictCursor)
query ='''
select city.city_name as '도시', sss.category_name as '소분류', sss.product_name as '제품명', 
sss.product_price as '가격', sss.year as 'year'
from city_tb as city 
   inner join 
   (select ppp.type_id , ppp.product_type , price.city_id , ppp.category_name , 
   ppp.product_name , price.product_price , price.year 
   from product_price_tb price
   inner join
      (select ttt.type_id, ttt.product_type, ttt.category_name, name.product_name , name.product_id
      from product_name_tb as name
      inner join 
         (select ptype.type_id, ptype.product_type, categ.category_name, categ.category_id 
         from product_type_tb as ptype
         inner join product_category_tb as categ
         on ptype.type_id = categ.type_id
         where ptype.type_id = 'B') as ttt
         on name.category_id = ttt.category_id) as ppp
      on price.product_id = ppp.product_id) as sss
on city.city_id = sss.city_id      
where sss.product_price <> 0
order by sss.year asc ;
'''	

cur.execute(query)
data = cur.fetchall()
fresh_dict = {}
freshDF = pd.DataFrame(data)
freshDF.head(10)
# Out:
#    도시  소분류                제품명     가격  year
# 0  서울   갈치       갈치(생물, 100g)  11051  2019
# 1  부산   갈치       갈치(생물, 100g)   9746  2019
# 2  대구   갈치       갈치(생물, 100g)   9766  2019
# 3  인천   갈치       갈치(생물, 100g)  10196  2019
# 4  광주   갈치       갈치(생물, 100g)  10687  2019
# 5  대전   갈치       갈치(생물, 100g)  11255  2019
# 6  울산   갈치       갈치(생물, 100g)   9234  2019
# 7  서울  고등어  고등어(생물, 300~500g)   3424  2019
# 8  부산  고등어  고등어(생물, 300~500g)   3440  2019
# 9  대구  고등어  고등어(생물, 300~500g)   3488  2019

# %%
datasDF = freshDF.groupby(['도시','year','소분류']).mean(numeric_only=True)
place_name = datasDF.index.levels[0].to_list()
for name in place_name:
    fresh_dict[name] = datasDF.xs('고등어',level=2).loc[name]['가격'].to_list()
for key, val in fresh_dict.items():
    plt.plot(range(2019,2024), val, label=key)
plt.legend()
plt.show()

# %%
cur.execute(query)
data = cur.fetchall()
fresh_dict = {}
freshDF = pd.DataFrame(data)
datasDF = freshDF.groupby(['도시','year','소분류']).mean(numeric_only=True)
place_name = datasDF.index.levels[0].to_list()
for name in place_name:
    fresh_dict[name] = datasDF.xs('대파',level=2).loc[name]['가격'].to_list()
for key, val in fresh_dict.items():
    plt.plot(range(2019,2024), val, label=key)
plt.legend()
plt.show()

# %%
cur.execute(query)
data = cur.fetchall()
fresh_dict = {}
freshDF = pd.DataFrame(data)
datasDF = freshDF.groupby(['도시','year','소분류']).mean(numeric_only=True)
place_name = datasDF.index.levels[0].to_list()
for name in place_name:
    fresh_dict[name] = datasDF.xs('돼지고기',level=2).loc[name]['가격'].to_list()
for key, val in fresh_dict.items():
    plt.plot(range(2019,2024), val, label=key)
plt.legend()
plt.show()

# %%
cur.execute(query)
data = cur.fetchall()
fresh_dict = {}
freshDF = pd.DataFrame(data)
datasDF = freshDF.groupby(['도시','year','소분류']).mean(numeric_only=True)
place_name = datasDF.index.levels[0].to_list()
for name in place_name:
    fresh_dict[name] = datasDF.xs('배추',level=2).loc[name]['가격'].to_list()
for key, val in fresh_dict.items():
    plt.plot(range(2019,2024), val, label=key)
plt.legend()
plt.show()

# %%
cur.execute(query)
data = cur.fetchall()
fresh_dict = {}
freshDF = pd.DataFrame(data)
datasDF = freshDF.groupby(['도시','year','소분류']).mean(numeric_only=True)
place_name = datasDF.index.levels[0].to_list()
for name in place_name:
    fresh_dict[name] = datasDF.xs('무',level=2).loc[name]['가격'].to_list()
for key, val in fresh_dict.items():
    plt.plot(range(2019,2024), val, label=key)
plt.legend()
plt.show()

# %%
cur.execute(query)
data = cur.fetchall()
fresh_dict = {}
freshDF = pd.DataFrame(data)
datasDF = freshDF.groupby(['도시','year','소분류']).mean(numeric_only=True)
place_name = datasDF.index.levels[0].to_list()
for name in place_name:
    fresh_dict[name] = datasDF.xs('갈치',level=2).loc[name]['가격'].to_list()
for key, val in fresh_dict.items():
    plt.plot(range(2019,2024), val, label=key)
plt.legend()
plt.show()

# %%
cur.execute(query)
data = cur.fetchall()
fresh_dict = {}
freshDF = pd.DataFrame(data)
datasDF = freshDF.groupby(['도시','year','소분류']).mean(numeric_only=True)
place_name = datasDF.index.levels[0].to_list()
for name in place_name:
    fresh_dict[name] = datasDF.xs('오징어',level=2).loc[name]['가격'].to_list()
for key, val in fresh_dict.items():
    plt.plot(range(2019,2024), val, label=key)
plt.legend()
plt.show()

# %%
cur.execute(query)
data = cur.fetchall()
fresh_dict = {}
freshDF = pd.DataFrame(data)
datasDF = freshDF.groupby(['도시','year','소분류']).mean(numeric_only=True)
place_name = datasDF.index.levels[0].to_list()
for name in place_name:
    fresh_dict[name] = datasDF.xs('조기',level=2).loc[name]['가격'].to_list()
for key, val in fresh_dict.items():
    plt.plot(range(2019,2024), val, label=key)
plt.legend()
plt.show()

# %%
cur.execute(query)
data = cur.fetchall()
fresh_dict = {}
freshDF = pd.DataFrame(data)
datasDF = freshDF.groupby(['도시','year','소분류']).mean(numeric_only=True)
place_name = datasDF.index.levels[0].to_list()
for name in place_name:
    fresh_dict[name] = datasDF.xs('당근',level=2).loc[name]['가격'].to_list()
for key, val in fresh_dict.items():
    plt.plot(range(2019,2024), val, label=key)
plt.legend()
plt.show()

# %%
cur.execute(query)
data = cur.fetchall()
fresh_dict = {}
freshDF = pd.DataFrame(data)
datasDF = freshDF.groupby(['도시','year','소분류']).mean(numeric_only=True)
place_name = datasDF.index.levels[0].to_list()
for name in place_name:
    fresh_dict[name] = datasDF.xs('시금치',level=2).loc[name]['가격'].to_list()
for key, val in fresh_dict.items():
    plt.plot(range(2019,2024), val, label=key)
plt.legend()
plt.show()

# %%
cur.execute(query)
data = cur.fetchall()
fresh_dict = {}
freshDF = pd.DataFrame(data)
datasDF = freshDF.groupby(['도시','year','소분류']).mean(numeric_only=True)
place_name = datasDF.index.levels[0].to_list()
for name in place_name:
    fresh_dict[name] = datasDF.xs('계란',level=2).loc[name]['가격'].to_list()
for key, val in fresh_dict.items():
    plt.plot(range(2019,2024), val, label=key)
plt.legend()
plt.show()

# %%
cur.execute(query)
data = cur.fetchall()
fresh_dict = {}
freshDF = pd.DataFrame(data)
datasDF = freshDF.groupby(['도시','year','소분류']).mean(numeric_only=True)
place_name = datasDF.index.levels[0].to_list()
for name in place_name:
    fresh_dict[name] = datasDF.xs('쇠고기',level=2).loc[name]['가격'].to_list()
for key, val in fresh_dict.items():
    plt.plot(range(2019,2024), val, label=key)
plt.legend()
plt.show()

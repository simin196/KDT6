# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import requests
import pandas as pd

cafeDF=pd.read_csv('hollys_branches.csv')
cafeDF.head()
# Out:
#    Unnamed: 0        city       name  \
# 0           0  경기 성남시 분당구     분당미금점2
# 1           1      인천 부평구    인천굴포천역점
# 2           2       대구 서구   대구팔달교DT점
# 3           3       인천 중구  인천공항교통센터점
# 4           4       부산 중구    한국선원센터점
#
#                                              address          phone
# 0     경기도 성남시 분당구 미금일로90번길 24 (구미동) 구미동 35-3, B1F~1F   031-713-7739
# 1  인천광역시 부평구 충선로209번길 49 (삼산동, 삼산노블시티프라자) 삼산동 463...  070-4400-4664
# 2                                    대구광역시 서구 팔달로 34   053-354-1212
# 3  인천광역시 중구 공항로 272 (운서동, 인천공항) 인천국제공항 제1여객터미널 지하...   032-743-3718
# 4  부산광역시 중구 충장대로9번길 66 (중앙동4가, 한국선원센터) (중앙동4가 74-...  070-4070-7506

# %%
for i in range(len(cafeDF)):
    print(f'[{i+1}]: 매장이름: {cafeDF.iloc[i][1]}, 지역: {cafeDF.iloc[i][2]}, 주소: {cafeDF.iloc[i][3]}, 전화번호:{cafeDF.iloc[i][4]}')\

print(f'전체 매장 수: {len(cafeDF)}')
# Out:
# [1]: 매장이름: 경기 성남시 분당구, 지역: 분당미금점2, 주소: 경기도 성남시 분당구 미금일로90번길 24 (구미동) 구미동 35-3, B1F~1F, 전화번호:031-713-7739
# [2]: 매장이름: 인천 부평구, 지역: 인천굴포천역점, 주소: 인천광역시 부평구 충선로209번길 49 (삼산동, 삼산노블시티프라자) 삼산동 463-2, 103,104,105호, 전화번호:070-4400-4664
# [3]: 매장이름: 대구 서구, 지역: 대구팔달교DT점, 주소: 대구광역시 서구 팔달로 34, 전화번호:053-354-1212
# [4]: 매장이름: 인천 중구, 지역: 인천공항교통센터점, 주소: 인천광역시 중구 공항로 272 (운서동, 인천공항) 인천국제공항 제1여객터미널 지하1층(실번호 2-32-07), 전화번호:032-743-3718
# [5]: 매장이름: 부산 중구, 지역: 한국선원센터점, 주소: 부산광역시 중구 충장대로9번길 66 (중앙동4가, 한국선원센터) (중앙동4가 74-7)1층, 전화번호:070-4070-7506
# [6]: 매장이름: 제주 제주시, 지역: 제주애월천덕로점, 주소: 제주특별자치도 제주시 애월읍 천덕로 238-1 다동 1층, 전화번호:064-799-6667
# [7]: 매장이름: 대구 달서구, 지역: 대구장기점, 주소: 대구광역시 달서구 장기로 268 (장기동) 1~2층, 전화번호:053-522-0666
# [8]: 매장이름: 부산 연제구, 지역: 부산연산점, 주소: 부산광역시 연제구 반송로 89 (연산동) 1층, 전화번호:051-989-3296
# [9]: 매장이름: 경북 김천시, 지역: 김천혁신도시점, 주소: 경상북도 김천시 혁신로 246 (율곡동) 1층, 전화번호:054-433-4333
# [10]: 매장이름: 경기 안양시 동안구, 지역: 평촌점, 주소: 경기도 안양시 동안구 관평로170번길 43 (관양동, 훼미리타운) 1층, 전화번호:031-385-3400
# ...

# %%
# def search_place(cafeDF):
#     while True:
#         place = input('검색할 매장의 지역을 입력해주세요: ')
#         if place.lower() == 'quit': 
#             print('종료합니다.')
#             break
#         place_list = place.split(' ')
#         cafeDF_result =cafeDF[cafeDF['매장주소'].map(lambda x: all(string in x for string in place_list))].reset_index(drop=True)
#         print(tabulate(cafeDF_result, headers='keys', tablefmt='psql', showindex=True))

# def run_prject():
#     key = int(input('과제를 선택해 주세요 (1, 2): '))-1
#     func_list = [all_view,search_place]
#     cafeDF = pd.read_csv('hollys_branches.csv')
#     func_list[key](cafeDF)
# run_prject()

# %%
'''
저장된 파일 읽고 
무한 반복문 >> quit입력으로 프로그램 종료 >> if문 break
입력받기 >> 지역 ex 대구 북구 >> .strip().split()로 나누고
나누어진 단어들 비교 >> 해당지역 매장이름, 주소, 전화번호 출력 
추가로 앞에 인덱스 1부터 시작
데이터 프레임 앞에 검색된 매장 수 기입 >> len()으로 사용
만약에 len()이 0이라면 >> 검색된 매장이 없습니다. print
'''
# Out:
# '\n저장된 파일 읽고 \n무한 반복문 >> quit입력으로 프로그램 종료 >> if문 break\n입력받기 >> 지역 ex 대구 북구 >> .strip().split()로 나누고\n나누어진 단어들 비교 >> 해당지역 매장이름, 주소, 전화번호 출력 \n추가로 앞에 인덱스 1부터 시작\n데이터 프레임 앞에 검색된 매장 수 기입 >> len()으로 사용\n만약에 len()이 0이라면 >> 검색된 매장이 없습니다. print\n'

# %%
#파일 먼저 받고
cafeDF = cafeDF.drop(cafeDF.columns[0], axis=1)
cafeDF.head()
# Out:
#          city       name                                            address  \
# 0  경기 성남시 분당구     분당미금점2     경기도 성남시 분당구 미금일로90번길 24 (구미동) 구미동 35-3, B1F~1F
# 1      인천 부평구    인천굴포천역점  인천광역시 부평구 충선로209번길 49 (삼산동, 삼산노블시티프라자) 삼산동 463...
# 2       대구 서구   대구팔달교DT점                                    대구광역시 서구 팔달로 34
# 3       인천 중구  인천공항교통센터점  인천광역시 중구 공항로 272 (운서동, 인천공항) 인천국제공항 제1여객터미널 지하...
# 4       부산 중구    한국선원센터점  부산광역시 중구 충장대로9번길 66 (중앙동4가, 한국선원센터) (중앙동4가 74-...
#
#            phone
# 0   031-713-7739
# 1  070-4400-4664
# 2   053-354-1212
# 3   032-743-3718
# 4  070-4070-7506

# %%
# while True:
# place = input('검색할 매장의 지역을 입력하세요: ')
place_list = ['대구', '북구']
# if place == 'quit':
#     print('종료 합니다.')
#     break
# place_list = place.strip().split()
cafeDF['address'].isin(place_list[0]) and cafeDF['address'].isin(place_list[1])

for 문으로 쭉
위에 빈 리스트 하나 두고
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 8
#       3 place_list = ['대구', '북구']
#       4 # if place == 'quit':
#       5 #     print('종료 합니다.')
#       6 #     break
#       7 # place_list = place.strip().split()
# ----> 8 cafeDF['address'].isin(place_list[0])
#
# File c:\Users\KDP-23\anaconda3\envs\py39\lib\site-packages\pandas\core\series.py:5559, in Series.isin(self, values)
#    5486 def isin(self, values) -> Series:
#    5487     """
#    5488     Whether elements in Series are contained in `values`.
#    5489
#    (...)
#    5557     dtype: bool
#    5558     """
# -> 5559     result = algorithms.isin(self._values, values)
#    5560     return self._constructor(result, index=self.index, copy=False).__finalize__(
#    5561         self, method="isin"
#    5562     )
#
# ...

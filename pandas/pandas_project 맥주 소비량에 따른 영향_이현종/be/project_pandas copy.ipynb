# %% [markdown]
# 1인 1일당 양곡 소비량

# %%
import pandas as pd

# %%
file_name=r'C:\Users\KDP-23\Desktop\KDT\pandas_project 맥주 소비량에 따른 영향\1인_1일당_양곡소비량_20240717165410.xlsx'
file_name2=r'C:\Users\KDP-23\Desktop\KDT\pandas_project 맥주 소비량에 따른 영향\1인당_연간_양곡소비량_20240717161923.xlsx'

# %%
onedayDF= pd.read_excel(file_name)

# %%
onedayDF.drop(0, inplace=True)
print(onedayDF, onedayDF.shape,sep='\n\n')
# Out:
#          시점    양곡계      쌀
# 1   2018.01  183.7  159.9
# 2   2018.02  196.8  173.9
# 3   2018.03  184.0  164.5
# 4   2018.04  195.9  177.6
# 5   2018.05  185.4  166.6
# 6   2018.06  192.0  165.6
# 7   2018.07  188.5  162.9
# 8   2018.08  187.8  165.2
# 9   2018.09  186.4  165.0
# 10  2018.10  188.7  165.4
# 11  2018.11  197.1  170.4
# 12  2018.12  195.5  166.9
# 13  2019.01  188.5  167.7
# 14  2019.02  194.5  171.4
# 15  2019.03  181.6  162.2
# 16  2019.04  180.6  162.9
# 17  2019.05  178.8  160.5
# 18  2019.06  183.5  162.0
# 19  2019.07  180.8  157.2
# 20  2019.08  176.1  153.9
# 21  2019.09  179.3  156.3
# 22  2019.10  178.6  153.6
# 23  2019.11  190.1  159.8
# 24  2019.12  184.2  158.5
# 25  2020.01  186.0  161.7
# 26  2020.02  183.0  160.2
# 27  2020.03  181.1  159.1
# 28  2020.04  185.8  163.6
# 29  2020.05  178.4  158.3
# 30  2020.06  178.5  157.2
# 31  2020.07  177.7  154.6
# 32  2020.08  175.6  152.8
# 33  2020.09  181.3  156.0
# 34  2020.10  179.0  154.5
# ...

# %% [markdown]
# - 년도별로 1일 섭취량 평균내서 년도별로 비교 >>> 1인당 섭취량이 점차 줄어든다는 결론 도출 객체.mean()

# %%
yearDF= pd.read_excel(file_name2)

# %% [markdown]
# 야는 농가 비농가를 분류하는거라 필요없을거 같은데??

# %%
print(yearDF, yearDF.shape,sep='\n\n')
# Out:
#       용도별    시점  양곡계-전가구 (kg)  양곡계-농가 (kg)  양곡계-비농가 (kg)  쌀-전가구 (kg)  \
# 0       계  2018          69.5        105.5          67.5        61.0
# 1       계  2019          67.4        104.2          65.4        59.2
# 2       계  2020          66.3        102.1          64.5        57.7
# 3       계  2021          65.0         99.5          63.3        56.9
# 4       계  2022          64.7         99.3          63.0        56.7
# 5    주부식용  2018          68.4         98.0          66.8        60.5
# 6    주부식용  2019          66.1         97.1          64.5        58.6
# 7    주부식용  2020          64.9         95.6          63.3        57.1
# 8    주부식용  2021          63.9         94.0          62.3        56.5
# 9    주부식용  2022          63.8         94.0          62.3        56.5
# 10  기타음식용  2018           1.1          7.5           0.7         0.5
# 11  기타음식용  2019           1.2          7.1           0.9         0.5
# 12  기타음식용  2020           1.5          6.5           1.2         0.5
# ...

# %% [markdown]
# -------------------------------------------

# %% [markdown]
# 1인당 연간 양곡 소비량

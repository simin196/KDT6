# %%
import pandas as pd
import numpy as np

# %%
df=r'C:\Users\KDP-23\Desktop\KDT\pandas\datasets\bike_rentals\bike_rentals.csv'

# %%
df=pd.read_csv(df)
df
# Out:
#                   datetime  season  holiday  workingday  weather   temp  \
# 0      2011-01-01 00:00:00       1        0           0        1   9.84
# 1      2011-01-01 01:00:00       1        0           0        1   9.02
# 2      2011-01-01 02:00:00       1        0           0        1   9.02
# 3      2011-01-01 03:00:00       1        0           0        1   9.84
# 4      2011-01-01 04:00:00       1        0           0        1   9.84
# ...                    ...     ...      ...         ...      ...    ...
# 10881  2012-12-19 19:00:00       4        0           1        1  15.58
# 10882  2012-12-19 20:00:00       4        0           1        1  14.76
# 10883  2012-12-19 21:00:00       4        0           1        1  13.94
# 10884  2012-12-19 22:00:00       4        0           1        1  13.94
# 10885  2012-12-19 23:00:00       4        0           1        1  13.12
#
#         atemp  humidity  windspeed  casual  registered  count
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10886 entries, 0 to 10885
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   datetime    10886 non-null  object
#  1   season      10886 non-null  int64
#  2   holiday     10886 non-null  int64
#  3   workingday  10886 non-null  int64
#  4   weather     10886 non-null  int64
#  5   temp        10886 non-null  float64
#  6   atemp       10886 non-null  float64
#  7   humidity    10886 non-null  int64
#  8   windspeed   10886 non-null  float64
#  9   casual      10886 non-null  int64
#  10  registered  10886 non-null  int64
#  11  count       10886 non-null  int64
# dtypes: float64(3), int64(8), object(1)
# memory usage: 1020.7+ KB

# %%
df.iloc[2,3]=np.nan

# %%
df.head(10)
# Out:
#               datetime  season  holiday  workingday  weather   temp   atemp  \
# 0  2011-01-01 00:00:00       1        0         0.0        1   9.84  14.395
# 1  2011-01-01 01:00:00       1        0         0.0        1   9.02  13.635
# 2  2011-01-01 02:00:00       1        0         NaN        1   9.02  13.635
# 3  2011-01-01 03:00:00       1        0         0.0        1   9.84  14.395
# 4  2011-01-01 04:00:00       1        0         0.0        1   9.84  14.395
# 5  2011-01-01 05:00:00       1        0         0.0        2   9.84  12.880
# 6  2011-01-01 06:00:00       1        0         0.0        1   9.02  13.635
# 7  2011-01-01 07:00:00       1        0         0.0        1   8.20  12.880
# 8  2011-01-01 08:00:00       1        0         0.0        1   9.84  14.395
# 9  2011-01-01 09:00:00       1        0         0.0        1  13.12  17.425
#
#    humidity  windspeed  casual  registered  count
# 0        81     0.0000       3          13     16
# ...

# %%
df.iloc[2:5, 3:6]
# Out:
#    workingday  weather  temp
# 2         NaN        1  9.02
# 3         0.0        1  9.84
# 4         0.0        1  9.84

# %%
df.index
# Out:
# RangeIndex(start=0, stop=10886, step=1)

# %%
df.columns
# Out:
# Index(['datetime', 'season', 'holiday', 'workingday', 'weather', 'temp',
#        'atemp', 'humidity', 'windspeed', 'casual', 'registered', 'count'],
#       dtype='object')

# %%
df.loc[2:4, 'workingday':'temp'] # 데이터 추출 [행, 열], # 슬라이싱에 한글로 있는 경우 => 그곳까지 나열한다. 정수랑 다름(정수는 -1)
# Out:
#    workingday  weather  temp
# 2         NaN        1  9.02
# 3         0.0        1  9.84
# 4         0.0        1  9.84

# %%
df.loc[df['season']==2] # columns에 season의 2의 값을 행으로 나열
# Out:
#                  datetime  season  holiday  workingday  weather   temp  \
# 1323  2011-04-01 00:00:00       2        0         1.0        3  10.66
# 1324  2011-04-01 01:00:00       2        0         1.0        3  10.66
# 1325  2011-04-01 02:00:00       2        0         1.0        3  10.66
# 1326  2011-04-01 03:00:00       2        0         1.0        2   9.84
# 1327  2011-04-01 04:00:00       2        0         1.0        2   9.84
# ...                   ...     ...      ...         ...      ...    ...
# 8146  2012-06-19 19:00:00       2        0         1.0        1  32.80
# 8147  2012-06-19 20:00:00       2        0         1.0        1  32.80
# 8148  2012-06-19 21:00:00       2        0         1.0        1  31.16
# 8149  2012-06-19 22:00:00       2        0         1.0        1  29.52
# 8150  2012-06-19 23:00:00       2        0         1.0        1  29.52
#
#        atemp  humidity  windspeed  casual  registered  count
# ...

# %%
df.loc[df['season']==2, 'casual':'count'] # 마지막 부분엔 " 'casual': " 으로도 가능
# Out:
#       casual  registered  count
# 1323       0           6      6
# 1324       0           4      4
# 1325       0           7      7
# 1326       0           4      4
# 1327       0           3      3
# ...      ...         ...    ...
# 8146      82         432    514
# 8147      59         399    458
# 8148      37         239    276
# 8149      51         240    291
# 8150      23         102    125
#
# [2733 rows x 3 columns]

# %%
df.loc[(df['season']!=1) & (df['weather']!=2)]
# Out:
#                   datetime  season  holiday  workingday  weather   temp  \
# 1323   2011-04-01 00:00:00       2        0         1.0        3  10.66
# 1324   2011-04-01 01:00:00       2        0         1.0        3  10.66
# 1325   2011-04-01 02:00:00       2        0         1.0        3  10.66
# 1328   2011-04-01 05:00:00       2        0         1.0        3   9.84
# 1329   2011-04-01 06:00:00       2        0         1.0        3   9.84
# ...                    ...     ...      ...         ...      ...    ...
# 10881  2012-12-19 19:00:00       4        0         1.0        1  15.58
# 10882  2012-12-19 20:00:00       4        0         1.0        1  14.76
# 10883  2012-12-19 21:00:00       4        0         1.0        1  13.94
# 10884  2012-12-19 22:00:00       4        0         1.0        1  13.94
# 10885  2012-12-19 23:00:00       4        0         1.0        1  13.12
#
#         atemp  humidity  windspeed  casual  registered  count
# ...

# %%
df.loc[~(df['season']==1) & ~(df['weather']==2)] # 부정 ~ 쓸려면 앞에 쓰는데 교집합 이나 합집합을 쓸때 각 항을()로 묶어줘야하고 부정은 ~()앞에 다가 위치한다.
# Out:
#                   datetime  season  holiday  workingday  weather   temp  \
# 1323   2011-04-01 00:00:00       2        0         1.0        3  10.66
# 1324   2011-04-01 01:00:00       2        0         1.0        3  10.66
# 1325   2011-04-01 02:00:00       2        0         1.0        3  10.66
# 1328   2011-04-01 05:00:00       2        0         1.0        3   9.84
# 1329   2011-04-01 06:00:00       2        0         1.0        3   9.84
# ...                    ...     ...      ...         ...      ...    ...
# 10881  2012-12-19 19:00:00       4        0         1.0        1  15.58
# 10882  2012-12-19 20:00:00       4        0         1.0        1  14.76
# 10883  2012-12-19 21:00:00       4        0         1.0        1  13.94
# 10884  2012-12-19 22:00:00       4        0         1.0        1  13.94
# 10885  2012-12-19 23:00:00       4        0         1.0        1  13.12
#
#         atemp  humidity  windspeed  casual  registered  count
# ...

# %%
df
# Out:
#                   datetime  season  holiday  workingday  weather   temp  \
# 0      2011-01-01 00:00:00       1        0         0.0        1   9.84
# 1      2011-01-01 01:00:00       1        0         0.0        1   9.02
# 2      2011-01-01 02:00:00       1        0         NaN        1   9.02
# 3      2011-01-01 03:00:00       1        0         0.0        1   9.84
# 4      2011-01-01 04:00:00       1        0         0.0        1   9.84
# ...                    ...     ...      ...         ...      ...    ...
# 10881  2012-12-19 19:00:00       4        0         1.0        1  15.58
# 10882  2012-12-19 20:00:00       4        0         1.0        1  14.76
# 10883  2012-12-19 21:00:00       4        0         1.0        1  13.94
# 10884  2012-12-19 22:00:00       4        0         1.0        1  13.94
# 10885  2012-12-19 23:00:00       4        0         1.0        1  13.12
#
#         atemp  humidity  windspeed  casual  registered  count
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10886 entries, 0 to 10885
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   datetime    10886 non-null  object
#  1   season      10886 non-null  int64
#  2   holiday     10886 non-null  int64
#  3   workingday  10885 non-null  float64
#  4   weather     10886 non-null  int64
#  5   temp        10886 non-null  float64
#  6   atemp       10886 non-null  float64
#  7   humidity    10886 non-null  int64
#  8   windspeed   10886 non-null  float64
#  9   casual      10886 non-null  int64
#  10  registered  10886 non-null  int64
#  11  count       10886 non-null  int64
# dtypes: float64(4), int64(7), object(1)
# memory usage: 1020.7+ KB

# %%
df.select_dtypes(include=int)
# Out:
#        season  holiday  weather  humidity  casual  registered  count
# 0           1        0        1        81       3          13     16
# 1           1        0        1        80       8          32     40
# 2           1        0        1        80       5          27     32
# 3           1        0        1        75       3          10     13
# 4           1        0        1        75       0           1      1
# ...       ...      ...      ...       ...     ...         ...    ...
# 10881       4        0        1        50       7         329    336
# 10882       4        0        1        57      10         231    241
# 10883       4        0        1        61       4         164    168
# 10884       4        0        1        61      12         117    129
# 10885       4        0        1        66       4          84     88
#
# [10886 rows x 7 columns]

# %%
df.select_dtypes(exclude=int)
# Out:
#                   datetime  workingday   temp   atemp  windspeed
# 0      2011-01-01 00:00:00         0.0   9.84  14.395     0.0000
# 1      2011-01-01 01:00:00         0.0   9.02  13.635     0.0000
# 2      2011-01-01 02:00:00         NaN   9.02  13.635     0.0000
# 3      2011-01-01 03:00:00         0.0   9.84  14.395     0.0000
# 4      2011-01-01 04:00:00         0.0   9.84  14.395     0.0000
# ...                    ...         ...    ...     ...        ...
# 10881  2012-12-19 19:00:00         1.0  15.58  19.695    26.0027
# 10882  2012-12-19 20:00:00         1.0  14.76  17.425    15.0013
# 10883  2012-12-19 21:00:00         1.0  13.94  15.910    15.0013
# 10884  2012-12-19 22:00:00         1.0  13.94  17.425     6.0032
# 10885  2012-12-19 23:00:00         1.0  13.12  16.665     8.9981
#
# [10886 rows x 5 columns]

# %%
df1=df.set_index('datetime')

# %%
df1
# Out:
#                      season  holiday  workingday  weather   temp   atemp  \
# datetime
# 2011-01-01 00:00:00       1        0         0.0        1   9.84  14.395
# 2011-01-01 01:00:00       1        0         0.0        1   9.02  13.635
# 2011-01-01 02:00:00       1        0         NaN        1   9.02  13.635
# 2011-01-01 03:00:00       1        0         0.0        1   9.84  14.395
# 2011-01-01 04:00:00       1        0         0.0        1   9.84  14.395
# ...                     ...      ...         ...      ...    ...     ...
# 2012-12-19 19:00:00       4        0         1.0        1  15.58  19.695
# 2012-12-19 20:00:00       4        0         1.0        1  14.76  17.425
# 2012-12-19 21:00:00       4        0         1.0        1  13.94  15.910
# 2012-12-19 22:00:00       4        0         1.0        1  13.94  17.425
# 2012-12-19 23:00:00       4        0         1.0        1  13.12  16.665
#
#                      humidity  windspeed  casual  registered  count
# datetime
# ...

# %%
df1.filter(like='00:00:00') #like에 포함된  쓰면 그냥
# Out:
# Empty DataFrame
# Columns: []
# ...

# %%
# df.filter(like=0) # >>> ERROR 띄움 >>> TypeError: Must pass either `items`, `like`, or `regex`

# %%
df1.filter(like="00:00:00", axis=0)
# Out:
#                      season  holiday  workingday  weather   temp   atemp  \
# datetime
# 2011-01-01 00:00:00       1        0         0.0        1   9.84  14.395
# 2011-01-02 00:00:00       1        0         0.0        2  18.86  22.725
# 2011-01-03 00:00:00       1        0         1.0        1   9.02   9.850
# 2011-01-04 00:00:00       1        0         1.0        1   6.56   9.090
# 2011-01-05 00:00:00       1        0         1.0        1   8.20  12.880
# ...                     ...      ...         ...      ...    ...     ...
# 2012-12-15 00:00:00       4        0         0.0        1  12.30  16.665
# 2012-12-16 00:00:00       4        0         0.0        2  14.76  18.940
# 2012-12-17 00:00:00       4        0         1.0        2  15.58  19.695
# 2012-12-18 00:00:00       4        0         1.0        2  18.04  21.970
# 2012-12-19 00:00:00       4        0         1.0        1  12.30  15.910
#
#                      humidity  windspeed  casual  registered  count
# datetime
# ...

# %%
df1.filter(items=['humidity','windspeed'])
# Out:
#                      humidity  windspeed
# datetime
# 2011-01-01 00:00:00        81     0.0000
# 2011-01-01 01:00:00        80     0.0000
# 2011-01-01 02:00:00        80     0.0000
# 2011-01-01 03:00:00        75     0.0000
# 2011-01-01 04:00:00        75     0.0000
# ...                       ...        ...
# 2012-12-19 19:00:00        50    26.0027
# 2012-12-19 20:00:00        57    15.0013
# 2012-12-19 21:00:00        61    15.0013
# 2012-12-19 22:00:00        61     6.0032
# 2012-12-19 23:00:00        66     8.9981
#
# [10886 rows x 2 columns]

# %%
df1.filter(regex='in.s') #>>>>>?????????????응???
# Out:
#                      windspeed
# datetime
# 2011-01-01 00:00:00     0.0000
# 2011-01-01 01:00:00     0.0000
# 2011-01-01 02:00:00     0.0000
# 2011-01-01 03:00:00     0.0000
# 2011-01-01 04:00:00     0.0000
# ...                        ...
# 2012-12-19 19:00:00    26.0027
# 2012-12-19 20:00:00    15.0013
# 2012-12-19 21:00:00    15.0013
# 2012-12-19 22:00:00     6.0032
# 2012-12-19 23:00:00     8.9981
#
# [10886 rows x 1 columns]

# %%
df.rename({2:'hello'})
# Out:
#                   datetime  season  holiday  workingday  weather   temp  \
# 0      2011-01-01 00:00:00       1        0         0.0        1   9.84
# 1      2011-01-01 01:00:00       1        0         0.0        1   9.02
# hello  2011-01-01 02:00:00       1        0         NaN        1   9.02
# 3      2011-01-01 03:00:00       1        0         0.0        1   9.84
# 4      2011-01-01 04:00:00       1        0         0.0        1   9.84
# ...                    ...     ...      ...         ...      ...    ...
# 10881  2012-12-19 19:00:00       4        0         1.0        1  15.58
# 10882  2012-12-19 20:00:00       4        0         1.0        1  14.76
# 10883  2012-12-19 21:00:00       4        0         1.0        1  13.94
# 10884  2012-12-19 22:00:00       4        0         1.0        1  13.94
# 10885  2012-12-19 23:00:00       4        0         1.0        1  13.12
#
#         atemp  humidity  windspeed  casual  registered  count
# ...

# %%
df.rename({'registered':'registered_user', 'casual':'unregistered_user'}, axis=1) # 변수명.rename({변경할 라벨}:{변경 라벨}) axis=0은 행(기본값-기본으로 생략), axis=1 열)
# Out:
#                   datetime  season  holiday  workingday  weather   temp  \
# 0      2011-01-01 00:00:00       1        0         0.0        1   9.84
# 1      2011-01-01 01:00:00       1        0         0.0        1   9.02
# 2      2011-01-01 02:00:00       1        0         NaN        1   9.02
# 3      2011-01-01 03:00:00       1        0         0.0        1   9.84
# 4      2011-01-01 04:00:00       1        0         0.0        1   9.84
# ...                    ...     ...      ...         ...      ...    ...
# 10881  2012-12-19 19:00:00       4        0         1.0        1  15.58
# 10882  2012-12-19 20:00:00       4        0         1.0        1  14.76
# 10883  2012-12-19 21:00:00       4        0         1.0        1  13.94
# 10884  2012-12-19 22:00:00       4        0         1.0        1  13.94
# 10885  2012-12-19 23:00:00       4        0         1.0        1  13.12
#
#         atemp  humidity  windspeed  unregistered_user  registered_user  count
# ...

# %%
df # but inplace을 하지않으면 변경되진 않는다.
# Out:
#                   datetime  season  holiday  workingday  weather   temp  \
# 0      2011-01-01 00:00:00       1        0         0.0        1   9.84
# 1      2011-01-01 01:00:00       1        0         0.0        1   9.02
# 2      2011-01-01 02:00:00       1        0         NaN        1   9.02
# 3      2011-01-01 03:00:00       1        0         0.0        1   9.84
# 4      2011-01-01 04:00:00       1        0         0.0        1   9.84
# ...                    ...     ...      ...         ...      ...    ...
# 10881  2012-12-19 19:00:00       4        0         1.0        1  15.58
# 10882  2012-12-19 20:00:00       4        0         1.0        1  14.76
# 10883  2012-12-19 21:00:00       4        0         1.0        1  13.94
# 10884  2012-12-19 22:00:00       4        0         1.0        1  13.94
# 10885  2012-12-19 23:00:00       4        0         1.0        1  13.12
#
#         atemp  humidity  windspeed  casual  registered  count
# ...

# %%
df.rename(columns={'registered':'registered_user', 'casual':'unregistered_user'}) # axis=1을 말고도 앞에 columns라고 명시하면 그 축에 맞춰서 변경한다.
# Out:
#                   datetime  season  holiday  workingday  weather   temp  \
# 0      2011-01-01 00:00:00       1        0         0.0        1   9.84
# 1      2011-01-01 01:00:00       1        0         0.0        1   9.02
# 2      2011-01-01 02:00:00       1        0         NaN        1   9.02
# 3      2011-01-01 03:00:00       1        0         0.0        1   9.84
# 4      2011-01-01 04:00:00       1        0         0.0        1   9.84
# ...                    ...     ...      ...         ...      ...    ...
# 10881  2012-12-19 19:00:00       4        0         1.0        1  15.58
# 10882  2012-12-19 20:00:00       4        0         1.0        1  14.76
# 10883  2012-12-19 21:00:00       4        0         1.0        1  13.94
# 10884  2012-12-19 22:00:00       4        0         1.0        1  13.94
# 10885  2012-12-19 23:00:00       4        0         1.0        1  13.12
#
#         atemp  humidity  windspeed  unregistered_user  registered_user  count
# ...

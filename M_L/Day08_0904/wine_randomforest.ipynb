# %% [markdown]
# #### Ensemble - RandomForest & ExtraTree
# - 배깅 방식의 앙상블 ==> 중복 랜덤 샘플 + 동일 모델(DT)
#     * 대표 알고리즘 : RandomForestC/R
# - 페이스팅 방식의 앙상블 ==> 랜덤 샘플 + 동일모델(DT), 중복X
#     * 대표 알고리즘 : ExtraTreeC/R

# %% [markdown]
# [목표] 와인분류 => 0과 1 2개 종류 분류

# %% [markdown]
# [1] 모듈 로딩 및 데이터 준비

# %%
# 모듈로딩
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# 파일경로
DATA_FILE = '../DATA/wine.csv'

# CSV ==> DataFrame
wineDF = pd.read_csv(DATA_FILE)

# %%
wineDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6497 entries, 0 to 6496
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   alcohol  6497 non-null   float64
#  1   sugar    6497 non-null   float64
#  2   pH       6497 non-null   float64
#  3   class    6497 non-null   float64
# dtypes: float64(4)
# memory usage: 203.2 KB

# %%
wineDF.head(3)
# Out:
#    alcohol  sugar    pH  class
# 0      9.4    1.9  3.51    0.0
# 1      9.8    2.6  3.20    0.0
# 2      9.8    2.3  3.26    0.0

# %%
# 타겟/라벨 클래스 분포
wineDF['class'].value_counts()
# Out:
# class
# 1.0    4898
# 0.0    1599
# Name: count, dtype: int64

# %%
wineDF.describe()
# Out:
#            alcohol        sugar           pH        class
# count  6497.000000  6497.000000  6497.000000  6497.000000
# mean     10.491801     5.443235     3.218501     0.753886
# std       1.192712     4.757804     0.160787     0.430779
# min       8.000000     0.600000     2.720000     0.000000
# 25%       9.500000     1.800000     3.110000     1.000000
# 50%      10.300000     3.000000     3.210000     1.000000
# 75%      11.300000     8.100000     3.320000     1.000000
# max      14.900000    65.800000     4.010000     1.000000

# %% [markdown]
# [2] 학습준비

# %%
# 학습용 & 테스트용 데이터셋 분할
from sklearn.model_selection import train_test_split

# %%
# 피쳐/독립변수와 타겟/라벨/종속변수 분리
featureDF= wineDF[wineDF.columns[:-1]]
targetSR = wineDF[wineDF.columns[-1]]

print(f'featureDF : {featureDF.shape}  targetSR : {targetSR.shape}')
# Out:
# featureDF : (6497, 3)  targetSR : (6497,)

# %%
# 학습용, 테스트용 데이터셋 분리
X_train, X_test, y_train, y_test = train_test_split(featureDF,
                                                    targetSR,
                                                    stratify=targetSR,
                                                    test_size=0.2,
                                                    random_state=10)

# %%
print(f'X_train: {X_train.shape}, {X_train.ndim}D')
print(f'X_test: {X_test.shape}, {X_test.ndim}D')
print(f'y_train: {y_train.shape}, {y_train.ndim}D')
print(f'y_test: {y_test.shape}, {y_test.ndim}D')
# Out:
# X_train: (5197, 3), 2D
# X_test: (1300, 3), 2D
# y_train: (5197,), 1D
# y_test: (1300,), 1D

# %% [markdown]
# [3] 학습 진행

# %%
# 학습방법 : 지도학습 ==> 분류
# 알고리즘 : 앙상블 => 배깅 => RandomForestClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
# 인스턴스 생성 => 100개의 내부 DT 모델에서 사용할 데이터샛 생성
#                 random_state 매개변수 설정으로 고정된 데이터셋 생성
#                 oob_score 매개변수 : 샘플 데이터셋 추출 후 남은 데이터셋 검증용으로 사용
lf_model = RandomForestClassifier(random_state=10,
                                  oob_score=True)
lf_model.fit(X_train,y_train)
# Out:
# RandomForestClassifier(oob_score=True, random_state=10)

# %%
# 모델 파라미터
print('classes_ :',lf_model.classes_)
print('n_classes_ :',lf_model.n_classes_)
print('feature_names_in_ :',lf_model.feature_names_in_)
print('n_features_in_ :',lf_model.n_features_in_)
print('feature_importances_ :',lf_model.feature_importances_)
# Out:
# classes_ : [0. 1.]
# n_classes_ : 2
# feature_names_in_ : ['alcohol' 'sugar' 'pH']
# n_features_in_ : 3
# feature_importances_ : [0.23617103 0.49952715 0.26430182]

# %%
# 모델 파라미터
print('classes_             :', lf_model.classes_)
for est in lf_model.estimators_: print(est) 
# 100번을 뽑았는 이렇게 모델을 뽑을 수 있다
# Out:
# classes_             : [0. 1.]
# DecisionTreeClassifier(max_features='sqrt', random_state=1165313289)
# DecisionTreeClassifier(max_features='sqrt', random_state=1283169405)
# DecisionTreeClassifier(max_features='sqrt', random_state=89128932)
# DecisionTreeClassifier(max_features='sqrt', random_state=2124247567)
# DecisionTreeClassifier(max_features='sqrt', random_state=574014784)
# DecisionTreeClassifier(max_features='sqrt', random_state=1902734705)
# DecisionTreeClassifier(max_features='sqrt', random_state=1068604539)
# DecisionTreeClassifier(max_features='sqrt', random_state=1425548444)
# DecisionTreeClassifier(max_features='sqrt', random_state=2141071321)
# DecisionTreeClassifier(max_features='sqrt', random_state=357864157)
# DecisionTreeClassifier(max_features='sqrt', random_state=965494256)
# DecisionTreeClassifier(max_features='sqrt', random_state=108111773)
# DecisionTreeClassifier(max_features='sqrt', random_state=850673521)
# DecisionTreeClassifier(max_features='sqrt', random_state=898541562)
# DecisionTreeClassifier(max_features='sqrt', random_state=1118970888)
# DecisionTreeClassifier(max_features='sqrt', random_state=1140597833)
# DecisionTreeClassifier(max_features='sqrt', random_state=726325504)
# DecisionTreeClassifier(max_features='sqrt', random_state=1132165610)
# DecisionTreeClassifier(max_features='sqrt', random_state=379416616)
# DecisionTreeClassifier(max_features='sqrt', random_state=645868022)
# DecisionTreeClassifier(max_features='sqrt', random_state=796114340)
# DecisionTreeClassifier(max_features='sqrt', random_state=789494131)
# DecisionTreeClassifier(max_features='sqrt', random_state=1947309584)
# DecisionTreeClassifier(max_features='sqrt', random_state=1359794532)
# DecisionTreeClassifier(max_features='sqrt', random_state=16957679)
# DecisionTreeClassifier(max_features='sqrt', random_state=1443416459)
# DecisionTreeClassifier(max_features='sqrt', random_state=52365366)
# DecisionTreeClassifier(max_features='sqrt', random_state=1678544216)
# DecisionTreeClassifier(max_features='sqrt', random_state=1342696811)
# DecisionTreeClassifier(max_features='sqrt', random_state=850926714)
# DecisionTreeClassifier(max_features='sqrt', random_state=483295806)
# DecisionTreeClassifier(max_features='sqrt', random_state=131497505)
# DecisionTreeClassifier(max_features='sqrt', random_state=952431816)
# DecisionTreeClassifier(max_features='sqrt', random_state=1621843812)
# DecisionTreeClassifier(max_features='sqrt', random_state=1253598158)
# DecisionTreeClassifier(max_features='sqrt', random_state=976828081)
# DecisionTreeClassifier(max_features='sqrt', random_state=1794326195)
# DecisionTreeClassifier(max_features='sqrt', random_state=175582262)
# DecisionTreeClassifier(max_features='sqrt', random_state=921595981)
# DecisionTreeClassifier(max_features='sqrt', random_state=564608453)
# DecisionTreeClassifier(max_features='sqrt', random_state=182726669)
# DecisionTreeClassifier(max_features='sqrt', random_state=1776687859)
# DecisionTreeClassifier(max_features='sqrt', random_state=610615705)
# DecisionTreeClassifier(max_features='sqrt', random_state=1197131134)
# DecisionTreeClassifier(max_features='sqrt', random_state=1603486349)
# DecisionTreeClassifier(max_features='sqrt', random_state=360353628)
# DecisionTreeClassifier(max_features='sqrt', random_state=747898198)
# DecisionTreeClassifier(max_features='sqrt', random_state=784396062)
# DecisionTreeClassifier(max_features='sqrt', random_state=1897659038)
# DecisionTreeClassifier(max_features='sqrt', random_state=1400512601)
# DecisionTreeClassifier(max_features='sqrt', random_state=1864075916)
# DecisionTreeClassifier(max_features='sqrt', random_state=452697409)
# DecisionTreeClassifier(max_features='sqrt', random_state=505805343)
# DecisionTreeClassifier(max_features='sqrt', random_state=1217952569)
# DecisionTreeClassifier(max_features='sqrt', random_state=56428324)
# DecisionTreeClassifier(max_features='sqrt', random_state=281592091)
# DecisionTreeClassifier(max_features='sqrt', random_state=645950994)
# DecisionTreeClassifier(max_features='sqrt', random_state=242425949)
# DecisionTreeClassifier(max_features='sqrt', random_state=433958989)
# DecisionTreeClassifier(max_features='sqrt', random_state=1140124054)
# DecisionTreeClassifier(max_features='sqrt', random_state=1310923671)
# DecisionTreeClassifier(max_features='sqrt', random_state=50629214)
# DecisionTreeClassifier(max_features='sqrt', random_state=92973816)
# DecisionTreeClassifier(max_features='sqrt', random_state=480792971)
# DecisionTreeClassifier(max_features='sqrt', random_state=1755133596)
# DecisionTreeClassifier(max_features='sqrt', random_state=1425423434)
# DecisionTreeClassifier(max_features='sqrt', random_state=1371108568)
# DecisionTreeClassifier(max_features='sqrt', random_state=256187785)
# DecisionTreeClassifier(max_features='sqrt', random_state=388519951)
# DecisionTreeClassifier(max_features='sqrt', random_state=1440960018)
# DecisionTreeClassifier(max_features='sqrt', random_state=1291496912)
# DecisionTreeClassifier(max_features='sqrt', random_state=1766015606)
# DecisionTreeClassifier(max_features='sqrt', random_state=489559111)
# DecisionTreeClassifier(max_features='sqrt', random_state=330091864)
# DecisionTreeClassifier(max_features='sqrt', random_state=1411675531)
# DecisionTreeClassifier(max_features='sqrt', random_state=1516308113)
# DecisionTreeClassifier(max_features='sqrt', random_state=201418158)
# DecisionTreeClassifier(max_features='sqrt', random_state=1889731719)
# DecisionTreeClassifier(max_features='sqrt', random_state=542399179)
# DecisionTreeClassifier(max_features='sqrt', random_state=523789084)
# DecisionTreeClassifier(max_features='sqrt', random_state=204380961)
# DecisionTreeClassifier(max_features='sqrt', random_state=995292628)
# DecisionTreeClassifier(max_features='sqrt', random_state=1371327226)
# DecisionTreeClassifier(max_features='sqrt', random_state=596066144)
# DecisionTreeClassifier(max_features='sqrt', random_state=854473176)
# DecisionTreeClassifier(max_features='sqrt', random_state=1146241068)
# DecisionTreeClassifier(max_features='sqrt', random_state=1532660357)
# DecisionTreeClassifier(max_features='sqrt', random_state=1425885188)
# DecisionTreeClassifier(max_features='sqrt', random_state=1510336583)
# DecisionTreeClassifier(max_features='sqrt', random_state=1330486616)
# DecisionTreeClassifier(max_features='sqrt', random_state=1093703512)
# DecisionTreeClassifier(max_features='sqrt', random_state=419112754)
# DecisionTreeClassifier(max_features='sqrt', random_state=1271145836)
# DecisionTreeClassifier(max_features='sqrt', random_state=1599413430)
# DecisionTreeClassifier(max_features='sqrt', random_state=1648994594)
# DecisionTreeClassifier(max_features='sqrt', random_state=2074558824)
# DecisionTreeClassifier(max_features='sqrt', random_state=1398061839)
# DecisionTreeClassifier(max_features='sqrt', random_state=2007481805)
# DecisionTreeClassifier(max_features='sqrt', random_state=708737880)
# DecisionTreeClassifier(max_features='sqrt', random_state=1613810319)

# %%
print(f'lf_model.oob_score_ :{lf_model.oob_score_}')
# Out:
# lf_model.oob_score_ :0.8993650182797768

# %% [markdown]
# [4] 성능평가

# %%
train_score = lf_model.score(X_train,y_train)
test_score = lf_model.score(X_test,y_test)

# %%
print(f'train_score: {train_score}, test_score: {test_score}')
# Out:
# train_score: 0.9976909755628247, test_score: 0.8930769230769231

# %% [markdown]
# [5] 튜닝
#
# - RandomizedSearchCV 하이퍼파라미터 최적화 클래스
#     + 범위가 넓은 하이퍼파라미터 설정에 좋음
#     + 지정된 범위에서 지정된 횟수 만큼 하이퍼파라미터를 추출하여 조합 진행

# %%
# 모듈로딩
from sklearn.model_selection import RandomizedSearchCV

# %%
# RandomizedSearchCV 하이퍼파라미터 설정 
params = {'max_depth': range(2,15), # 정수는 range , 실수는 numpy에 arrange 사용
          'min_samples_leaf': range(5,16),
          'criterion': ['gini', 'entropy', 'log_loss']}

# %%
rf_model = RandomForestClassifier(random_state=7)

# %%
searchCV = RandomizedSearchCV(rf_model,
                            param_distributions=params,
                            n_iter=50,
                            verbose=4)

# %%
searchCV.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# [CV 1/5] END criterion=entropy, max_depth=2, min_samples_leaf=14;, score=0.754 total time=   0.1s
# [CV 2/5] END criterion=entropy, max_depth=2, min_samples_leaf=14;, score=0.754 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=2, min_samples_leaf=14;, score=0.755 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=2, min_samples_leaf=14;, score=0.754 total time=   0.1s
# [CV 5/5] END criterion=entropy, max_depth=2, min_samples_leaf=14;, score=0.754 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=12, min_samples_leaf=8;, score=0.880 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=12, min_samples_leaf=8;, score=0.872 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=12, min_samples_leaf=8;, score=0.876 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=12, min_samples_leaf=8;, score=0.867 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=12, min_samples_leaf=8;, score=0.876 total time=   0.2s
# [CV 1/5] END criterion=entropy, max_depth=7, min_samples_leaf=7;, score=0.869 total time=   0.1s
# [CV 2/5] END criterion=entropy, max_depth=7, min_samples_leaf=7;, score=0.863 total time=   0.1s
# [CV 3/5] END criterion=entropy, max_depth=7, min_samples_leaf=7;, score=0.865 total time=   0.2s
# [CV 4/5] END criterion=entropy, max_depth=7, min_samples_leaf=7;, score=0.857 total time=   0.2s
# [CV 5/5] END criterion=entropy, max_depth=7, min_samples_leaf=7;, score=0.873 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=4, min_samples_leaf=14;, score=0.859 total time=   0.1s
# [CV 2/5] END criterion=gini, max_depth=4, min_samples_leaf=14;, score=0.841 total time=   0.1s
# [CV 3/5] END criterion=gini, max_depth=4, min_samples_leaf=14;, score=0.844 total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=4, min_samples_leaf=14;, score=0.843 total time=   0.1s
# [CV 5/5] END criterion=gini, max_depth=4, min_samples_leaf=14;, score=0.844 total time=   0.1s
# [CV 1/5] END criterion=gini, max_depth=10, min_samples_leaf=6;, score=0.880 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=10, min_samples_leaf=6;, score=0.870 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=10, min_samples_leaf=6;, score=0.874 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=10, min_samples_leaf=6;, score=0.865 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=10, min_samples_leaf=6;, score=0.880 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=5, min_samples_leaf=10;, score=0.870 total time=   0.1s
# [CV 2/5] END criterion=gini, max_depth=5, min_samples_leaf=10;, score=0.852 total time=   0.1s
# [CV 3/5] END criterion=gini, max_depth=5, min_samples_leaf=10;, score=0.864 total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=5, min_samples_leaf=10;, score=0.860 total time=   0.1s
# [CV 5/5] END criterion=gini, max_depth=5, min_samples_leaf=10;, score=0.858 total time=   0.1s
# [CV 1/5] END criterion=log_loss, max_depth=7, min_samples_leaf=5;, score=0.873 total time=   0.2s
# [CV 2/5] END criterion=log_loss, max_depth=7, min_samples_leaf=5;, score=0.866 total time=   0.2s
# [CV 3/5] END criterion=log_loss, max_depth=7, min_samples_leaf=5;, score=0.860 total time=   0.1s
# [CV 4/5] END criterion=log_loss, max_depth=7, min_samples_leaf=5;, score=0.855 total time=   0.2s
# [CV 5/5] END criterion=log_loss, max_depth=7, min_samples_leaf=5;, score=0.868 total time=   0.2s
# [CV 1/5] END criterion=log_loss, max_depth=11, min_samples_leaf=7;, score=0.878 total time=   0.2s
# [CV 2/5] END criterion=log_loss, max_depth=11, min_samples_leaf=7;, score=0.868 total time=   0.3s
# [CV 3/5] END criterion=log_loss, max_depth=11, min_samples_leaf=7;, score=0.877 total time=   0.2s
# [CV 4/5] END criterion=log_loss, max_depth=11, min_samples_leaf=7;, score=0.866 total time=   0.2s
# [CV 5/5] END criterion=log_loss, max_depth=11, min_samples_leaf=7;, score=0.885 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=3, min_samples_leaf=11;, score=0.833 total time=   0.1s
# [CV 2/5] END criterion=gini, max_depth=3, min_samples_leaf=11;, score=0.815 total time=   0.1s
# [CV 3/5] END criterion=gini, max_depth=3, min_samples_leaf=11;, score=0.802 total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=3, min_samples_leaf=11;, score=0.824 total time=   0.1s
# [CV 5/5] END criterion=gini, max_depth=3, min_samples_leaf=11;, score=0.830 total time=   0.1s
# [CV 1/5] END criterion=entropy, max_depth=5, min_samples_leaf=7;, score=0.866 total time=   0.1s
# [CV 2/5] END criterion=entropy, max_depth=5, min_samples_leaf=7;, score=0.858 total time=   0.1s
# [CV 3/5] END criterion=entropy, max_depth=5, min_samples_leaf=7;, score=0.859 total time=   0.1s
# [CV 4/5] END criterion=entropy, max_depth=5, min_samples_leaf=7;, score=0.857 total time=   0.1s
# [CV 5/5] END criterion=entropy, max_depth=5, min_samples_leaf=7;, score=0.859 total time=   0.1s
# [CV 1/5] END criterion=log_loss, max_depth=4, min_samples_leaf=6;, score=0.856 total time=   0.1s
# [CV 2/5] END criterion=log_loss, max_depth=4, min_samples_leaf=6;, score=0.837 total time=   0.1s
# [CV 3/5] END criterion=log_loss, max_depth=4, min_samples_leaf=6;, score=0.843 total time=   0.1s
# [CV 4/5] END criterion=log_loss, max_depth=4, min_samples_leaf=6;, score=0.844 total time=   0.1s
# [CV 5/5] END criterion=log_loss, max_depth=4, min_samples_leaf=6;, score=0.843 total time=   0.1s
# [CV 1/5] END criterion=log_loss, max_depth=13, min_samples_leaf=10;, score=0.877 total time=   0.2s
# [CV 2/5] END criterion=log_loss, max_depth=13, min_samples_leaf=10;, score=0.867 total time=   0.2s
# [CV 3/5] END criterion=log_loss, max_depth=13, min_samples_leaf=10;, score=0.872 total time=   0.2s
# [CV 4/5] END criterion=log_loss, max_depth=13, min_samples_leaf=10;, score=0.867 total time=   0.2s
# [CV 5/5] END criterion=log_loss, max_depth=13, min_samples_leaf=10;, score=0.876 total time=   0.2s
# [CV 1/5] END criterion=entropy, max_depth=7, min_samples_leaf=12;, score=0.873 total time=   0.2s
# [CV 2/5] END criterion=entropy, max_depth=7, min_samples_leaf=12;, score=0.865 total time=   0.1s
# [CV 3/5] END criterion=entropy, max_depth=7, min_samples_leaf=12;, score=0.863 total time=   0.1s
# [CV 4/5] END criterion=entropy, max_depth=7, min_samples_leaf=12;, score=0.856 total time=   0.2s
# [CV 5/5] END criterion=entropy, max_depth=7, min_samples_leaf=12;, score=0.870 total time=   0.2s
# [CV 1/5] END criterion=log_loss, max_depth=11, min_samples_leaf=13;, score=0.873 total time=   0.2s
# [CV 2/5] END criterion=log_loss, max_depth=11, min_samples_leaf=13;, score=0.863 total time=   0.2s
# [CV 3/5] END criterion=log_loss, max_depth=11, min_samples_leaf=13;, score=0.867 total time=   0.2s
# [CV 4/5] END criterion=log_loss, max_depth=11, min_samples_leaf=13;, score=0.865 total time=   0.2s
# [CV 5/5] END criterion=log_loss, max_depth=11, min_samples_leaf=13;, score=0.873 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=7, min_samples_leaf=7;, score=0.873 total time=   0.1s
# [CV 2/5] END criterion=gini, max_depth=7, min_samples_leaf=7;, score=0.864 total time=   0.1s
# [CV 3/5] END criterion=gini, max_depth=7, min_samples_leaf=7;, score=0.871 total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=7, min_samples_leaf=7;, score=0.860 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=7, min_samples_leaf=7;, score=0.869 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=12, min_samples_leaf=13;, score=0.871 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=12, min_samples_leaf=13;, score=0.864 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=12, min_samples_leaf=13;, score=0.871 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=12, min_samples_leaf=13;, score=0.861 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=12, min_samples_leaf=13;, score=0.871 total time=   0.2s
# [CV 1/5] END criterion=entropy, max_depth=12, min_samples_leaf=6;, score=0.879 total time=   0.2s
# [CV 2/5] END criterion=entropy, max_depth=12, min_samples_leaf=6;, score=0.878 total time=   0.2s
# [CV 3/5] END criterion=entropy, max_depth=12, min_samples_leaf=6;, score=0.877 total time=   0.2s
# [CV 4/5] END criterion=entropy, max_depth=12, min_samples_leaf=6;, score=0.865 total time=   0.2s
# [CV 5/5] END criterion=entropy, max_depth=12, min_samples_leaf=6;, score=0.885 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=5, min_samples_leaf=13;, score=0.869 total time=   0.1s
# [CV 2/5] END criterion=gini, max_depth=5, min_samples_leaf=13;, score=0.853 total time=   0.1s
# [CV 3/5] END criterion=gini, max_depth=5, min_samples_leaf=13;, score=0.862 total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=5, min_samples_leaf=13;, score=0.856 total time=   0.1s
# [CV 5/5] END criterion=gini, max_depth=5, min_samples_leaf=13;, score=0.857 total time=   0.1s
# [CV 1/5] END criterion=gini, max_depth=2, min_samples_leaf=7;, score=0.754 total time=   0.1s
# [CV 2/5] END criterion=gini, max_depth=2, min_samples_leaf=7;, score=0.756 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=2, min_samples_leaf=7;, score=0.755 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=2, min_samples_leaf=7;, score=0.771 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=2, min_samples_leaf=7;, score=0.754 total time=   0.1s
# [CV 1/5] END criterion=entropy, max_depth=12, min_samples_leaf=14;, score=0.877 total time=   0.3s
# [CV 2/5] END criterion=entropy, max_depth=12, min_samples_leaf=14;, score=0.867 total time=   0.2s
# [CV 3/5] END criterion=entropy, max_depth=12, min_samples_leaf=14;, score=0.868 total time=   0.2s
# [CV 4/5] END criterion=entropy, max_depth=12, min_samples_leaf=14;, score=0.862 total time=   0.2s
# [CV 5/5] END criterion=entropy, max_depth=12, min_samples_leaf=14;, score=0.875 total time=   0.2s
# [CV 1/5] END criterion=log_loss, max_depth=12, min_samples_leaf=5;, score=0.876 total time=   0.2s
# [CV 2/5] END criterion=log_loss, max_depth=12, min_samples_leaf=5;, score=0.885 total time=   0.2s
# [CV 3/5] END criterion=log_loss, max_depth=12, min_samples_leaf=5;, score=0.885 total time=   0.2s
# [CV 4/5] END criterion=log_loss, max_depth=12, min_samples_leaf=5;, score=0.868 total time=   0.2s
# [CV 5/5] END criterion=log_loss, max_depth=12, min_samples_leaf=5;, score=0.883 total time=   0.2s
# [CV 1/5] END criterion=entropy, max_depth=9, min_samples_leaf=8;, score=0.875 total time=   0.2s
# [CV 2/5] END criterion=entropy, max_depth=9, min_samples_leaf=8;, score=0.871 total time=   0.2s
# [CV 3/5] END criterion=entropy, max_depth=9, min_samples_leaf=8;, score=0.872 total time=   0.2s
# [CV 4/5] END criterion=entropy, max_depth=9, min_samples_leaf=8;, score=0.861 total time=   0.2s
# [CV 5/5] END criterion=entropy, max_depth=9, min_samples_leaf=8;, score=0.872 total time=   0.2s
# [CV 1/5] END criterion=entropy, max_depth=13, min_samples_leaf=11;, score=0.873 total time=   0.2s
# [CV 2/5] END criterion=entropy, max_depth=13, min_samples_leaf=11;, score=0.867 total time=   0.2s
# [CV 3/5] END criterion=entropy, max_depth=13, min_samples_leaf=11;, score=0.870 total time=   0.2s
# [CV 4/5] END criterion=entropy, max_depth=13, min_samples_leaf=11;, score=0.860 total time=   0.2s
# [CV 5/5] END criterion=entropy, max_depth=13, min_samples_leaf=11;, score=0.874 total time=   0.2s
# [CV 1/5] END criterion=log_loss, max_depth=8, min_samples_leaf=8;, score=0.876 total time=   0.2s
# [CV 2/5] END criterion=log_loss, max_depth=8, min_samples_leaf=8;, score=0.865 total time=   0.2s
# [CV 3/5] END criterion=log_loss, max_depth=8, min_samples_leaf=8;, score=0.867 total time=   0.2s
# [CV 4/5] END criterion=log_loss, max_depth=8, min_samples_leaf=8;, score=0.859 total time=   0.2s
# [CV 5/5] END criterion=log_loss, max_depth=8, min_samples_leaf

#                                         'min_samples_leaf': range(5, 16)},
#                    verbose=4)

# %%
# 모델 파라미터
print(f'[ searchCV.best_params_ ] {searchCV.best_params_}')
print(f'[ searchCV.best_score_ ] {searchCV.best_score_}')
print(f'[ searchCV.best_estimator_ ] {searchCV.best_estimator_}')

cv_resultDF = pd.DataFrame(searchCV.cv_results_)
cv_resultDF
###????????????????????? 점수가 다를수있나??
# Out:
# [ searchCV.best_params_ ] {'min_samples_leaf': 5, 'max_depth': 12, 'criterion': 'log_loss'}
# [ searchCV.best_score_ ] 0.8791606204190421
# [ searchCV.best_estimator_ ] RandomForestClassifier(criterion='log_loss', max_depth=12, min_samples_leaf=5,
#                        random_state=7)
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.167805      0.055055         0.010081        0.001270
# 1        0.269218      0.013854         0.016255        0.000995
# 2        0.240869      0.008472         0.014318        0.001238
# 3        0.173297      0.008965         0.011955        0.001369
# 4        0.275554      0.006125         0.016477        0.001246
# 5        0.200957      0.009424         0.014561        0.001413
# 6        0.258725      0.026102         0.014687        0.001902
# 7        0.312114      0.037496         0.016425        0.001765
# 8        0.167121      0.011903         0.011932        0.001580
# 9        0.202280      0.008880         0.013532        0.001978
# 10       0.185542      0.010427         0.011818        0.000762
# 11       0.273890      0.006969         0.016179        0.001332
# 12       0.245312      0.013767         0.015724        0.001378
# 13       0.269175      0.010507         0.016295        0.001182
# 14       0.233198      0.011727         0.015394        0.000974
# 15       0.278002      0.021211         0.016526        0.001775
# 16       0.307038      0.006461         0.016161        0.000278
# 17       0.194614      0.009854         0.013708        0.002724
# 18       0.139004      0.004588         0.010668        0.001149
# 19       0.277406      0.037205         0.017181        0.001426
# 20       0.302976      0.003638         0.016101        0.000759
# 21       0.263724      0.003145         0.014598        0.000739
# 22       0.265361      0.005408         0.016275        0.001104
# 23       0.248949      0.005862         0.015242        0.001229
# 24       0.274297      0.004603         0.015468        0.000701
# 25       0.257278      0.002344         0.014880        0.000570
# 26       0.271346      0.005183         0.015769        0.000715
# 27       0.171056      0.001813         0.012577        0.000995
# 28       0.276435      0.006633         0.016175        0.000757
# 29       0.209242      0.005460         0.014927        0.000915
# 30       0.287463      0.011276         0.016276        0.001159
# 31       0.267037      0.005076         0.015203        0.000786
# 32       0.248171      0.003756         0.016237        0.001190
# 33       0.204051      0.002913         0.014220        0.000542
# 34       0.226158      0.002214         0.016169        0.001178
# 35       0.241436      0.002574         0.016376        0.001186
# 36       0.191582      0.002453         0.013503        0.001059
# 37       0.145341      0.004253         0.010282        0.000930
# 38       0.275287      0.004102         0.016316        0.000593
# 39       0.238922      0.001861         0.014897        0.001015
# 40       0.240203      0.007199         0.015932        0.000923
# 41       0.253480      0.002747         0.015986        0.000883
# 42       0.172954      0.005470         0.011813        0.000789
# 43       0.265259      0.005474         0.015238        0.000415
# 44       0.191654      0.003381         0.012994        0.000952
# 45       0.262872      0.002875         0.015036        0.000684
# 46       0.251147      0.008826         0.015658        0.001962
# 47       0.174665      0.004642         0.012506        0.002248
# 48       0.214472      0.003331         0.015386        0.001190
# 49       0.223341      0.004537         0.016681        0.002155
#
#    param_min_samples_leaf param_max_depth param_criterion  \
# 0                      14               2         entropy
# 1                       8              12            gini
# 2                       7               7         entropy
# 3                      14               4            gini
# 4                       6              10            gini
# 5                      10               5            gini
# 6                       5               7        log_loss
# 7                       7              11        log_loss
# 8                      11               3            gini
# 9                       7               5         entropy
# 10                      6               4        log_loss
# 11                     10              13        log_loss
# 12                     12               7         entropy
# 13                     13              11        log_loss
# 14                      7               7            gini
# 15                     13              12            gini
# 16                      6              12         entropy
# 17                     13               5            gini
# 18                      7               2            gini
# 19                     14              12         entropy
# 20                      5              12        log_loss
# 21                      8               9         entropy
# 22                     11              13         entropy
# 23                      8               8        log_loss
# 24                      9              12        log_loss
# 25                      9               9         entropy
# 26                     10              14         entropy
# 27                     13               4        log_loss
# 28                      7              12            gini
# 29                     14               6        log_loss
# 30                      6              14            gini
# 31                      8              14            gini
# 32                     14               9        log_loss
# 33                     13               6            gini
# 34                      6               7            gini
# 35                     14              14            gini
# 36                     14               5         entropy
# 37                      9               2         entropy
# 38                      7              13            gini
# 39                      9               8            gini
# 40                     14               8        log_loss
# 41                     10              10            gini
# 42                     11               4            gini
# 43                     11              14        log_loss
# 44                     15               5        log_loss
# 45                      9              10            gini
# 46                     14              10        log_loss
# 47                     10               4         entropy
# 48                     12               6        log_loss
# 49                     15               7        log_loss
#
#                                                params  split0_test_score  \
# 0   {'min_samples_leaf': 14, 'max_depth': 2, 'crit...           0.753846
# 1   {'min_samples_leaf': 8, 'max_depth': 12, 'crit...           0.879808
# 2   {'min_samples_leaf': 7, 'max_depth': 7, 'crite...           0.869231
# 3   {'min_samples_leaf': 14, 'max_depth': 4, 'crit...           0.858654
# 4   {'min_samples_leaf': 6, 'max_depth': 10, 'crit...           0.879808
# 5   {'min_samples_leaf': 10, 'max_depth': 5, 'crit...           0.870192
# 6   {'min_samples_leaf': 5, 'max_depth': 7, 'crite...           0.873077
# 7   {'min_samples_leaf': 7, 'max_depth': 11, 'crit...           0.877885
# 8   {'min_samples_leaf': 11, 'max_depth': 3, 'crit...           0.832692
# 9   {'min_samples_leaf': 7, 'max_depth': 5, 'crite...           0.866346
# 10  {'min_samples_leaf': 6, 'max_depth': 4, 'crite...           0.855769
# 11  {'min_samples_leaf': 10, 'max_depth': 13, 'cri...           0.876923
# 12  {'min_samples_leaf': 12, 'max_depth': 7, 'crit...           0.873077
# 13  {'min_samples_leaf': 13, 'max_depth': 11, 'cri...           0.873077
# 14  {'min_samples_leaf': 7, 'max_depth': 7, 'crite...           0.873077
# 15  {'min_samples_leaf': 13, 'max_depth': 12, 'cri...           0.871154
# 16  {'min_samples_leaf': 6, 'max_depth': 12, 'crit...           0.878846
# 17  {'min_samples_leaf': 13, 'max_depth': 5, 'crit...           0.869231
# 18  {'min_samples_leaf': 7, 'max_depth': 2, 'crite...           0.753846
# 19  {'min_samples_leaf': 14, 'max_depth': 12, 'cri...           0.876923
# 20  {'min_samples_leaf': 5, 'max_depth': 12, 'crit...           0.875962
# 21  {'min_samples_leaf': 8, 'max_depth': 9, 'crite...           0.875000
# 22  {'min_samples_leaf': 11, 'max_depth': 13, 'cri...           0.873077
# 23  {'min_samples_leaf': 8, 'max_depth': 8, 'crite...           0.875962
# 24  {'min_samples_leaf': 9, 'max_depth': 12, 'crit...           0.876923
# 25  {'min_samples_leaf': 9, 'max_depth': 9, 'crite...           0.873077
# 26  {'min_samples_leaf': 10, 'max_depth': 14, 'cri...           0.876923
# 27  {'min_samples_leaf': 13, 'max_depth': 4, 'crit...           0.853846
# 28  {'min_samples_leaf': 7, 'max_depth': 12, 'crit...           0.873077
# 29  {'min_samples_leaf': 14, 'max_depth': 6, 'crit...           0.868269
# 30  {'min_samples_leaf': 6, 'max_depth': 14, 'crit...           0.880769
# 31  {'min_samples_leaf': 8, 'max_depth': 14, 'crit...           0.878846
# 32  {'min_samples_leaf': 14, 'max_depth': 9, 'crit...           0.878846
# 33  {'min_samples_leaf': 13, 'max_depth': 6, 'crit...           0.869231
# 34  {'min_samples_leaf': 6, 'max_depth': 7, 'crite...           0.875962
# 35  {'min_samples_leaf': 14, 'max_depth': 14, 'cri...           0.874038
# 36  {'min_samples_leaf': 14, 'max_depth': 5, 'crit...           0.865385
# 37  {'min_samples_leaf': 9, 'max_depth': 2, 'crite...           0.753846
# 38  {'min_samples_leaf': 7, 'max_depth': 13, 'crit...           0.878846
# 39  {'min_samples_leaf': 9, 'max_depth': 8, 'crite...           0.877885
# 40  {'min_samples_leaf': 14, 'max_depth': 8, 'crit...           0.874038
# 41  {'min_samples_leaf': 10, 'max_depth': 10, 'cri...           0.874038
# 42  {'min_samples_leaf': 11, 'max_depth': 4, 'crit...           0.858654
# 43  {'min_samples_leaf': 11, 'max_depth': 14, 'cri...           0.874038
# 44  {'min_samples_leaf': 15, 'max_depth': 5, 'crit...           0.864423
# 45  {'min_samples_leaf': 9, 'max_depth': 10, 'crit...           0.875962
# 46  {'min_samples_leaf': 14, 'max_depth': 10, 'cri...           0.870192
# 47  {'min_samples_leaf': 10, 'max_depth': 4, 'crit...           0.854808
# 48  {'min_samples_leaf': 12, 'max_depth': 6, 'crit...           0.870192
# 49  {'min_samples_leaf': 15, 'max_depth': 7, 'crit...           0.872115
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.753846           0.754572           0.753609
# 1            0.872115           0.875842           0.867180
# 2            0.863462           0.865255           0.856593
# 3            0.841346           0.844081           0.843118
# 4            0.870192           0.873917           0.865255
# 5            0.851923           0.864293           0.860443
# 6            0.866346           0.860443           0.854668
# 7            0.868269           0.876805           0.866218
# 8            0.815385           0.801732           0.823869
# 9            0.857692           0.859480           0.856593
# 10           0.836538           0.843118           0.844081
# 11           0.867308           0.871992           0.867180
# 12           0.865385           0.863330           0.855630
# 13           0.862500           0.867180           0.865255
# 14           0.864423           0.871030           0.860443
# 15           0.864423           0.871030           0.861405
# 16           0.877885           0.876805           0.865255
# 17           0.852885           0.862368           0.855630
# 18           0.755769           0.754572           0.770934
# 19           0.867308           0.868142           0.862368
# 20           0.884615           0.884504           0.868142
# 21           0.871154           0.871992           0.861405
# 22           0.867308           0.870067           0.860443
# 23           0.865385           0.867180           0.859480
# 24           0.868269           0.877767           0.865255

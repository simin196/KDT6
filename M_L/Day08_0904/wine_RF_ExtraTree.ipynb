# %% [markdown]
# #### Ensemble - RandomForest & ExtraTree
# - 배깅 방식의 앙상블 ==> 중복 랜덤 샘플 + 동일 모델(DT)
#     * 대표 알고리즘 : RandomForestC/R
# - 페이스팅 방식의 앙상블 ==> 랜덤 샘플 + 동일모델(DT), 중복X
#     * 대표 알고리즘 : ExtraTreeC/R

# %% [markdown]
# [목표] 와인분류 => 0과 1 2개 종류 분류

# %% [markdown]
# [1] 모듈 로딩 및 데이터 준비

# %%
# 모듈로딩
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# 파일경로
DATA_FILE = '../DATA/wine.csv'

# CSV ==> DataFrame
wineDF = pd.read_csv(DATA_FILE)

# %%
wineDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6497 entries, 0 to 6496
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   alcohol  6497 non-null   float64
#  1   sugar    6497 non-null   float64
#  2   pH       6497 non-null   float64
#  3   class    6497 non-null   float64
# dtypes: float64(4)
# memory usage: 203.2 KB

# %%
wineDF.head(3)
# Out:
#    alcohol  sugar    pH  class
# 0      9.4    1.9  3.51    0.0
# 1      9.8    2.6  3.20    0.0
# 2      9.8    2.3  3.26    0.0

# %%
# 타겟/라벨 클래스 분포
wineDF['class'].value_counts()
# Out:
# class
# 1.0    4898
# 0.0    1599
# Name: count, dtype: int64

# %%
wineDF.describe()
# Out:
#            alcohol        sugar           pH        class
# count  6497.000000  6497.000000  6497.000000  6497.000000
# mean     10.491801     5.443235     3.218501     0.753886
# std       1.192712     4.757804     0.160787     0.430779
# min       8.000000     0.600000     2.720000     0.000000
# 25%       9.500000     1.800000     3.110000     1.000000
# 50%      10.300000     3.000000     3.210000     1.000000
# 75%      11.300000     8.100000     3.320000     1.000000
# max      14.900000    65.800000     4.010000     1.000000

# %% [markdown]
# [2] 학습준비

# %%
# 학습용 & 테스트용 데이터셋 분할
from sklearn.model_selection import train_test_split

# %%
# 피쳐/독립변수와 타겟/라벨/종속변수 분리
featureDF= wineDF[wineDF.columns[:-1]]
targetSR = wineDF[wineDF.columns[-1]]

print(f'featureDF : {featureDF.shape}  targetSR : {targetSR.shape}')
# Out:
# featureDF : (6497, 3)  targetSR : (6497,)

# %%
# 학습용, 테스트용 데이터셋 분리
X_train, X_test, y_train, y_test = train_test_split(featureDF,
                                                    targetSR,
                                                    stratify=targetSR,
                                                    test_size=0.2,
                                                    random_state=10)

# %%
print(f'X_train: {X_train.shape}, {X_train.ndim}D')
print(f'X_test: {X_test.shape}, {X_test.ndim}D')
print(f'y_train: {y_train.shape}, {y_train.ndim}D')
print(f'y_test: {y_test.shape}, {y_test.ndim}D')
# Out:
# X_train: (5197, 3), 2D
# X_test: (1300, 3), 2D
# y_train: (5197,), 1D
# y_test: (1300,), 1D

# %% [markdown]
# [3] 학습 진행 - ExtraTreesClassifier

# %%
# 학습방법 : 지도학습 ==> 분류
# 알고리즘 : 앙상블 => 배깅 => ExtraTreesClassifier 
from sklearn.ensemble import ExtraTreesClassifier

# %%
# 인스턴스 생성 => 100개의 내부 DT 모델에서 사용할 데이터샛 생성
#                 random_state 매개변수 설정으로 고정된 데이터셋 생성
#                 oob_score 매개변수 : 샘플 데이터셋 추출 후 남은 데이터셋 검증용으로 사용
lf_model = ExtraTreesClassifier(random_state=7)

# 학습
lf_model.fit(X_train, y_train)
# Out:
# ExtraTreesClassifier(random_state=7)

# %%
# 모델 파라미터
print(f'classes_            : {lf_model.classes_}')
print(f'n_classes_          : {lf_model.n_classes_}개')
print()
print(f'feature_names_in_    : {lf_model.feature_names_in_}')
print(f'n_features_in_       : {lf_model.n_features_in_}개')
print(f'feature_importances_ : {lf_model.feature_importances_}')
# Out:
# classes_            : [0. 1.]
# n_classes_          : 2개
#
# feature_names_in_    : ['alcohol' 'sugar' 'pH']
# n_features_in_       : 3개
# feature_importances_ : [0.18859051 0.52297152 0.28843797]

# %%
# 모델 파라미터
print(f'classes_            : {lf_model.estimator_}')
for est in lf_model.estimators_:
    print(est) # 100번을 뽑았는 이렇게 모델을 뽑을 수 있다
# Out:
# classes_            : ExtraTreeClassifier()
# ExtraTreeClassifier(random_state=327741615)
# ExtraTreeClassifier(random_state=976413892)
# ExtraTreeClassifier(random_state=1202242073)
# ExtraTreeClassifier(random_state=1369975286)
# ExtraTreeClassifier(random_state=1882953283)
# ExtraTreeClassifier(random_state=2053951699)
# ExtraTreeClassifier(random_state=959775639)
# ExtraTreeClassifier(random_state=1956722279)
# ExtraTreeClassifier(random_state=2052949340)
# ExtraTreeClassifier(random_state=1322904761)
# ExtraTreeClassifier(random_state=165338510)
# ExtraTreeClassifier(random_state=1133316631)
# ExtraTreeClassifier(random_state=4812360)
# ExtraTreeClassifier(random_state=372560217)
# ExtraTreeClassifier(random_state=309457262)
# ExtraTreeClassifier(random_state=1801189930)
# ExtraTreeClassifier(random_state=1152936666)
# ExtraTreeClassifier(random_state=68334472)
# ExtraTreeClassifier(random_state=2146978983)
# ExtraTreeClassifier(random_state=119248870)
# ExtraTreeClassifier(random_state=769786948)
# ExtraTreeClassifier(random_state=1583990192)
# ExtraTreeClassifier(random_state=1304549247)
# ExtraTreeClassifier(random_state=1420943751)
# ExtraTreeClassifier(random_state=1636129708)
# ExtraTreeClassifier(random_state=1687674368)
# ExtraTreeClassifier(random_state=283194443)
# ExtraTreeClassifier(random_state=748743479)
# ExtraTreeClassifier(random_state=1237575930)
# ExtraTreeClassifier(random_state=740097030)
# ExtraTreeClassifier(random_state=1759190803)
# ExtraTreeClassifier(random_state=833359292)
# ExtraTreeClassifier(random_state=916483116)
# ExtraTreeClassifier(random_state=1485942463)
# ExtraTreeClassifier(random_state=1941857605)
# ExtraTreeClassifier(random_state=1844809528)
# ExtraTreeClassifier(random_state=1852015768)
# ExtraTreeClassifier(random_state=1127788727)
# ExtraTreeClassifier(random_state=106941365)
# ExtraTreeClassifier(random_state=1077017712)
# ExtraTreeClassifier(random_state=431854331)
# ExtraTreeClassifier(random_state=1094761661)
# ExtraTreeClassifier(random_state=1933291456)
# ExtraTreeClassifier(random_state=1508798754)
# ExtraTreeClassifier(random_state=989143352)
# ExtraTreeClassifier(random_state=747550921)
# ExtraTreeClassifier(random_state=208262606)
# ExtraTreeClassifier(random_state=1248819750)
# ExtraTreeClassifier(random_state=1757192964)
# ExtraTreeClassifier(random_state=1879603694)
# ExtraTreeClassifier(random_state=571958409)
# ExtraTreeClassifier(random_state=1927692119)
# ExtraTreeClassifier(random_state=100556259)
# ExtraTreeClassifier(random_state=1652057283)
# ExtraTreeClassifier(random_state=1075502152)
# ExtraTreeClassifier(random_state=1535344467)
# ExtraTreeClassifier(random_state=725906352)
# ExtraTreeClassifier(random_state=830456065)
# ExtraTreeClassifier(random_state=2008983232)
# ExtraTreeClassifier(random_state=431532432)
# ExtraTreeClassifier(random_state=879820150)
# ExtraTreeClassifier(random_state=2072909727)
# ExtraTreeClassifier(random_state=2107823453)
# ExtraTreeClassifier(random_state=488352684)
# ExtraTreeClassifier(random_state=1599380060)
# ExtraTreeClassifier(random_state=1938096892)
# ExtraTreeClassifier(random_state=2050422343)
# ExtraTreeClassifier(random_state=1497897239)
# ExtraTreeClassifier(random_state=1571487242)
# ExtraTreeClassifier(random_state=1187621609)
# ExtraTreeClassifier(random_state=1451346723)
# ExtraTreeClassifier(random_state=1917728192)
# ExtraTreeClassifier(random_state=1153832253)
# ExtraTreeClassifier(random_state=1966724487)
# ExtraTreeClassifier(random_state=1348596887)
# ExtraTreeClassifier(random_state=771276892)
# ExtraTreeClassifier(random_state=311923447)
# ExtraTreeClassifier(random_state=612959456)
# ExtraTreeClassifier(random_state=1185621653)
# ExtraTreeClassifier(random_state=358664548)
# ExtraTreeClassifier(random_state=1944945571)
# ExtraTreeClassifier(random_state=202873313)
# ExtraTreeClassifier(random_state=1516030531)
# ExtraTreeClassifier(random_state=1332338555)
# ExtraTreeClassifier(random_state=676025563)
# ExtraTreeClassifier(random_state=1214271969)
# ExtraTreeClassifier(random_state=1590645779)
# ExtraTreeClassifier(random_state=1808153499)
# ExtraTreeClassifier(random_state=1971789316)
# ExtraTreeClassifier(random_state=1861190419)
# ExtraTreeClassifier(random_state=941989921)
# ExtraTreeClassifier(random_state=1798548603)
# ExtraTreeClassifier(random_state=1773786398)
# ExtraTreeClassifier(random_state=2088312505)
# ExtraTreeClassifier(random_state=1745574629)
# ExtraTreeClassifier(random_state=1260873545)
# ExtraTreeClassifier(random_state=775033821)
# ExtraTreeClassifier(random_state=1474484177)
# ExtraTreeClassifier(random_state=1035597695)
# ExtraTreeClassifier(random_state=1289946527)

# %% [markdown]
# [4] 성능평가

# %%
train_score = lf_model.score(X_train,y_train)
test_score = lf_model.score(X_test,y_test)

# %%
print(f'train_score: {train_score}, test_score: {test_score}')
# Out:
# train_score: 0.9976909755628247, test_score: 0.8853846153846154

# %% [markdown]
# [5] 튜닝
#
# - RandomizedSearchCV 하이퍼파라미터 최적화 클래스
#     + 범위가 넓은 하이퍼파라미터 설정에 좋음
#     + 지정된 범위에서 지정된 횟수 만큼 하이퍼파라미터를 추출하여 조합 진행

# %%
# 모듈로딩
from sklearn.model_selection import RandomizedSearchCV

# %%
# RandomizedSearchCV 하이퍼파라미터 설정 
params = {'max_depth': range(2,15), # 정수는 range , 실수는 numpy에 arrange 사용
          'min_samples_leaf': range(5,16),
          'criterion': ['gini', 'entropy', 'log_loss']}

# %%
rf_model=ExtraTreesClassifier( n_estimators=300, random_state=7)

# %%
searchCV = RandomizedSearchCV(rf_model, 
                              param_distributions=params,
                              n_iter=50,
                              verbose=4)

# %%
searchCV.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# [CV 1/5] END criterion=gini, max_depth=14, min_samples_leaf=5;, score=0.754 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=14, min_samples_leaf=5;, score=0.754 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=14, min_samples_leaf=5;, score=0.755 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=14, min_samples_leaf=5;, score=0.754 total time=   0.3s
# [CV 5/5] END criterion=gini, max_depth=14, min_samples_leaf=5;, score=0.768 total time=   0.3s
# [CV 1/5] END criterion=gini, max_depth=12, min_samples_leaf=14;, score=0.754 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=12, min_samples_leaf=14;, score=0.754 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=12, min_samples_leaf=14;, score=0.755 total time=   0.4s
# [CV 4/5] END criterion=gini, max_depth=12, min_samples_leaf=14;, score=0.754 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=12, min_samples_leaf=14;, score=0.754 total time=   0.3s
# [CV 1/5] END criterion=entropy, max_depth=9, min_samples_leaf=5;, score=0.754 total time=   0.2s
# [CV 2/5] END criterion=entropy, max_depth=9, min_samples_leaf=5;, score=0.754 total time=   0.2s
# [CV 3/5] END criterion=entropy, max_depth=9, min_samples_leaf=5;, score=0.755 total time=   0.2s
# [CV 4/5] END criterion=entropy, max_depth=9, min_samples_leaf=5;, score=0.754 total time=   0.2s
# [CV 5/5] END criterion=entropy, max_depth=9, min_samples_leaf=5;, score=0.754 total time=   0.2s
# [CV 1/5] END criterion=entropy, max_depth=5, min_samples_leaf=13;, score=0.754 total time=   0.2s
# [CV 2/5] END criterion=entropy, max_depth=5, min_samples_leaf=13;, score=0.754 total time=   0.2s
# [CV 3/5] END criterion=entropy, max_depth=5, min_samples_leaf=13;, score=0.755 total time=   0.2s
# [CV 4/5] END criterion=entropy, max_depth=5, min_samples_leaf=13;, score=0.754 total time=   0.2s
# [CV 5/5] END criterion=entropy, max_depth=5, min_samples_leaf=13;, score=0.754 total time=   0.2s
# [CV 1/5] END criterion=entropy, max_depth=11, min_samples_leaf=8;, score=0.754 total time=   0.2s
# [CV 2/5] END criterion=entropy, max_depth=11, min_samples_leaf=8;, score=0.754 total time=   0.2s
# [CV 3/5] END criterion=entropy, max_depth=11, min_samples_leaf=8;, score=0.755 total time=   0.2s
# [CV 4/5] END criterion=entropy, max_depth=11, min_samples_leaf=8;, score=0.754 total time=   0.2s
# [CV 5/5] END criterion=entropy, max_depth=11, min_samples_leaf=8;, score=0.754 total time=   0.3s
# [CV 1/5] END criterion=entropy, max_depth=12, min_samples_leaf=7;, score=0.754 total time=   0.2s
# [CV 2/5] END criterion=entropy, max_depth=12, min_samples_leaf=7;, score=0.754 total time=   0.2s
# [CV 3/5] END criterion=entropy, max_depth=12, min_samples_leaf=7;, score=0.755 total time=   0.2s
# [CV 4/5] END criterion=entropy, max_depth=12, min_samples_leaf=7;, score=0.754 total time=   0.2s
# [CV 5/5] END criterion=entropy, max_depth=12, min_samples_leaf=7;, score=0.754 total time=   0.2s
# [CV 1/5] END criterion=log_loss, max_depth=11, min_samples_leaf=10;, score=0.754 total time=   0.2s
# [CV 2/5] END criterion=log_loss, max_depth=11, min_samples_leaf=10;, score=0.754 total time=   0.2s
# [CV 3/5] END criterion=log_loss, max_depth=11, min_samples_leaf=10;, score=0.755 total time=   0.2s
# [CV 4/5] END criterion=log_loss, max_depth=11, min_samples_leaf=10;, score=0.754 total time=   0.2s
# [CV 5/5] END criterion=log_loss, max_depth=11, min_samples_leaf=10;, score=0.754 total time=   0.2s
# [CV 1/5] END criterion=entropy, max_depth=11, min_samples_leaf=11;, score=0.754 total time=   0.2s
# [CV 2/5] END criterion=entropy, max_depth=11, min_samples_leaf=11;, score=0.754 total time=   0.2s
# [CV 3/5] END criterion=entropy, max_depth=11, min_samples_leaf=11;, score=0.755 total time=   0.2s
# [CV 4/5] END criterion=entropy, max_depth=11, min_samples_leaf=11;, score=0.754 total time=   0.2s
# [CV 5/5] END criterion=entropy, max_depth=11, min_samples_leaf=11;, score=0.754 total time=   0.2s
# [CV 1/5] END criterion=log_loss, max_depth=6, min_samples_leaf=15;, score=0.754 total time=   0.2s
# [CV 2/5] END criterion=log_loss, max_depth=6, min_samples_leaf=15;, score=0.754 total time=   0.2s
# [CV 3/5] END criterion=log_loss, max_depth=6, min_samples_leaf=15;, score=0.755 total time=   0.2s
# [CV 4/5] END criterion=log_loss, max_depth=6, min_samples_leaf=15;, score=0.754 total time=   0.2s
# [CV 5/5] END criterion=log_loss, max_depth=6, min_samples_leaf=15;, score=0.754 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=9, min_samples_leaf=10;, score=0.754 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=9, min_samples_leaf=10;, score=0.754 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=9, min_samples_leaf=10;, score=0.755 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=9, min_samples_leaf=10;, score=0.754 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=9, min_samples_leaf=10;, score=0.754 total time=   0.3s
# [CV 1/5] END criterion=gini, max_depth=3, min_samples_leaf=8;, score=0.754 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=3, min_samples_leaf=8;, score=0.754 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=3, min_samples_leaf=8;, score=0.755 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=3, min_samples_leaf=8;, score=0.754 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=3, min_samples_leaf=8;, score=0.754 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=13, min_samples_leaf=8;, score=0.754 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=13, min_samples_leaf=8;, score=0.754 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=13, min_samples_leaf=8;, score=0.755 total time=   0.3s
# [CV 4/5] END criterion=gini, max_depth=13, min_samples_leaf=8;, score=0.754 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=13, min_samples_leaf=8;, score=0.754 total time=   0.3s
# [CV 1/5] END criterion=log_loss, max_depth=2, min_samples_leaf=5;, score=0.754 total time=   0.2s
# [CV 2/5] END criterion=log_loss, max_depth=2, min_samples_leaf=5;, score=0.754 total time=   0.2s
# [CV 3/5] END criterion=log_loss, max_depth=2, min_samples_leaf=5;, score=0.755 total time=   0.2s
# [CV 4/5] END criterion=log_loss, max_depth=2, min_samples_leaf=5;, score=0.754 total time=   0.2s
# [CV 5/5] END criterion=log_loss, max_depth=2, min_samples_leaf=5;, score=0.754 total time=   0.2s
# [CV 1/5] END criterion=entropy, max_depth=7, min_samples_leaf=6;, score=0.754 total time=   0.2s
# [CV 2/5] END criterion=entropy, max_depth=7, min_samples_leaf=6;, score=0.754 total time=   0.2s
# [CV 3/5] END criterion=entropy, max_depth=7, min_samples_leaf=6;, score=0.755 total time=   0.2s
# [CV 4/5] END criterion=entropy, max_depth=7, min_samples_leaf=6;, score=0.754 total time=   0.2s
# [CV 5/5] END criterion=entropy, max_depth=7, min_samples_leaf=6;, score=0.754 total time=   0.3s
# [CV 1/5] END criterion=log_loss, max_depth=2, min_samples_leaf=9;, score=0.754 total time=   0.2s
# [CV 2/5] END criterion=log_loss, max_depth=2, min_samples_leaf=9;, score=0.754 total time=   0.2s
# [CV 3/5] END criterion=log_loss, max_depth=2, min_samples_leaf=9;, score=0.755 total time=   0.2s
# [CV 4/5] END criterion=log_loss, max_depth=2, min_samples_leaf=9;, score=0.754 total time=   0.2s
# [CV 5/5] END criterion=log_loss, max_depth=2, min_samples_leaf=9;, score=0.754 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=5, min_samples_leaf=10;, score=0.754 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=5, min_samples_leaf=10;, score=0.754 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=5, min_samples_leaf=10;, score=0.755 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=5, min_samples_leaf=10;, score=0.754 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=5, min_samples_leaf=10;, score=0.754 total time=   0.2s
# [CV 1/5] END criterion=entropy, max_depth=11, min_samples_leaf=6;, score=0.754 total time=   0.2s
# [CV 2/5] END criterion=entropy, max_depth=11, min_samples_leaf=6;, score=0.754 total time=   0.3s
# [CV 3/5] END criterion=entropy, max_depth=11, min_samples_leaf=6;, score=0.755 total time=   0.2s
# [CV 4/5] END criterion=entropy, max_depth=11, min_samples_leaf=6;, score=0.754 total time=   0.2s
# [CV 5/5] END criterion=entropy, max_depth=11, min_samples_leaf=6;, score=0.754 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=6, min_samples_leaf=15;, score=0.754 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=6, min_samples_leaf=15;, score=0.754 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=6, min_samples_leaf=15;, score=0.755 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=6, min_samples_leaf=15;, score=0.754 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=6, min_samples_leaf=15;, score=0.754 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=3, min_samples_leaf=5;, score=0.754 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=3, min_samples_leaf=5;, score=0.754 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=3, min_samples_leaf=5;, score=0.755 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=3, min_samples_leaf=5;, score=0.754 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=3, min_samples_leaf=5;, score=0.754 total time=   0.2s
# [CV 1/5] END criterion=log_loss, max_depth=14, min_samples_leaf=11;, score=0.754 total time=   0.2s
# [CV 2/5] END criterion=log_loss, max_depth=14, min_samples_leaf=11;, score=0.754 total time=   0.2s
# [CV 3/5] END criterion=log_loss, max_depth=14, min_samples_leaf=11;, score=0.755 total time=   0.2s
# [CV 4/5] END criterion=log_loss, max_depth=14, min_samples_leaf=11;, score=0.754 total time=   0.2s
# [CV 5/5] END criterion=log_loss, max_depth=14, min_samples_leaf=11;, score=0.754 total time=   0.3s
# [CV 1/5] END criterion=log_loss, max_depth=10, min_samples_leaf=12;, score=0.754 total time=   0.2s
# [CV 2/5] END criterion=log_loss, max_depth=10, min_samples_leaf=12;, score=0.754 total time=   0.2s
# [CV 3/5] END criterion=log_loss, max_depth=10, min_samples_leaf=12;, score=0.755 total time=   0.2s
# [CV 4/5] END criterion=log_loss, max_depth=10, min_samples_leaf=12;, score=0.754 total time=   0.2s
# [CV 5/5] END criterion=log_loss, max_depth=10, min_samples_leaf=12;, score=0.754 total time=   0.3s
# [CV 1/5] END criterion=gini, max_depth=11, min_samples_leaf=6;, score=0.754 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=11, min_samples_leaf=6;, score=0.754 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=11, min_samples_leaf=6;, score=0.755 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=11, min_samples_leaf=6;, score=0.754 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=11, min_samples_leaf=6;, score=0.754 total time=   0.3s
# [CV 1/5] END criterion=log_loss, max_depth=3, min_samples_leaf=10;, score=0.754 total time=   0.2s
# [CV 2/5] END criterion=log_loss, max_depth=3, min_samples_leaf=10;, score=0.754 total time=   0.2s
# [CV 3/5] END criterion=log_loss, max_depth=3, min_samples_leaf=10;, score=0.755 total time=   0.2s
# [CV 4/5] END criterion=log_loss, max_depth=3, min_samples_leaf=10;, score=0.754 total time=   0.2s
# [CV 5/5] END criterion=log_loss, max_depth=3, min_samples_leaf=10;, score=0.754 total time=   0.2s
# [CV 1/5] END criterion=log_loss, max_depth=9, min_samples_leaf=6;, score=0.754 total time=   0.2s
# [CV 2/5] END criterion=log_loss, max_depth=9, min_samples_leaf=6;, score=0.754 total time=   0.2s
# [CV 3/5] END criterion=log_loss, max_depth=9, min_samples_leaf=6;, score=0.755 total time=   0.2s
# [CV 4/5] END criterion=log_loss, max_depth=9, min_samples_leaf=6;, score=0.754 total time=   0.2s
# [CV 5/5] END criterion=log_loss, max_depth=9, min_samples_leaf=6;, score=0.754 total time=   0.3s
# [CV 1/5] END criterion=log_loss, max_depth=6, min_samples_leaf=10;, score=0.754 total time=   0.2s
# [CV 2/5] END criterion=log_loss, max_depth=6, min_samples_leaf=10;, score=0.754 total time=   0.2s
# [CV 3/5] END criterion=log_loss, max_depth=6, min_samples_leaf=10;, score=0.755 total time=   0.2s
# [CV 4/5] END criterion=log_loss, max_depth=6, min_samples_leaf=10;, score=0.754 total time=   0.3s
# [CV 5/5] END criterion=log_loss, max_depth=6, min_samples_leaf=10;, score=0.754 total time=   0.2s
# [CV 1/5] END criterion=log_loss, max_depth=9, min_samples_leaf=11;, score=0.754 total time=   0.2s
# [CV 2/5] END criterion=log_loss, max_depth=9, min_samples_leaf=11;, score=0.754 total time=   0.2s
# [CV 3/5] END criterion=log_loss, max_depth=9, min_samples_leaf=11;, score=0.755 total time=   0.2s
# [CV 4/5] END criterion=log_loss, max_depth=9, min_samples_leaf=11;, score=0.754 total time=   0.2s
# [CV 5/5] END criterion=log_loss, max_depth=9, min_samples_leaf=11;, score=0.754 total time=   0.2s
# [CV 1/5] END criterion=entropy, max_depth=5, min_samples_leaf=14;, score=0.754 total time=   0.2s
# [CV 2/5] END criterion=entropy, max_depth=5, min_samples_leaf=14;, score=0.754 total time=   0.2s
# [CV 3/5] END criterion=entropy, max_depth=5, min_samples_leaf=14;, score=0.755 total time=   0.2s
# [CV 4/5] END criterion=entropy, max_depth=5, min_samples_leaf=14;, score=0.754 total time=   0.2s
# [CV 5/5] END criterion=entropy, max_depth=5, min_samples_leaf=14;, score=0.754 total time=   0.2s
# [CV 1/5] END criterion=log_loss, max_depth=12, min_samples_leaf=7;, score=0.754 total time=   0.2s
# [CV 2/5] END criterion=log_loss, max_depth=12, min_samples_leaf=7;, score=0.754 total time=   0.2s
# [CV 3/5] END criterion=log_loss, max_depth=12, min_samples_leaf=7;, score=0.755 total time=   0.2s
# [CV 4/5] END criterion=log_loss, max_depth=12, min_samples_leaf=7;, score=0.754 total time=   0.2s
# [CV 5/5] END criterion=log_loss, max_depth=12, min_samples_leaf=7;, score=0.754 total time=   0.2s
# [CV 1/5] END criterion=entropy, max_depth=13, min_samples_leaf=15;, score=0.754 total time=   0.2s
# [CV 2/5] END criterion=entropy, max_depth=13, min_samples_leaf=15;, score=0.754 total time=   0.2s
# [CV 3/5] END criterion=entropy, max_depth=13, min_samples_leaf=15;, score=0.755 total time=   0.2s
# [CV 4/5] END criterion=entropy, max_depth=13, min_samples_leaf=15;, score=0.754 total time=   0.2s
# [CV 5/5] END criterion=entropy, max_depth=13, min_samples_leaf=15;, score=0.754 total time=   0.2s
# [CV 1/5] END criterion=entropy, max_depth=3, min_samples_leaf=15;, score=0.754 total time=   0.2s
# [CV 2/5] END criterion=entropy, max_depth=3, min_samples_leaf=15;, score=0.754 total time=   0.2s
# [CV 3/5] END criterion=entropy, max_depth=3, min_samples_leaf=15;, score=0.755 total time=   0.2s
# [CV 4/5] END criterion=entropy, max_depth=3, min_samples_leaf=15;, score=0.754 total time=   0.2s
# [CV 5/5] END criterion=entropy, max_depth=3, min_samples_leaf=15;, score=0.754 total time=   0.2s
# [CV 1/5] END criterion=log_loss, max_depth=4, min_samples_leaf=14;, score=0.754 total time=   0.2s
# [CV 2/5] END criterion=log_loss, max_depth=4, min_samples_leaf=14;, score=0.754 total time=   0.2s
# [CV 3/5] END criterion=log_loss, max_depth=4, min_samples_leaf=14;, score=0.755 total time=   0.2s
# [CV 4/5] END criterion=log_loss, max_depth=4, min_samples_leaf=14;, score=0.754 total time=   0.2s
# [CV 5/5] END criterion=log_loss, max_depth=4, min_samples_leaf=14;, score=0.754 total time=   0.2s
# [CV 1/5] END criterion=entropy, max_depth=10, min_samples_leaf=11;, score=0.754 total time=   0.2s
# [CV 2/5] END criterion=entropy, max_depth=10, min_samples_leaf=11;, score=0.754 total time=   0.2s
# [CV 3/5] END criterion=entropy, max_depth=10, min_samples_leaf=11;, score=0.755 total time=   0.2s
# [CV 4/5] END criterion=entropy, max_depth=10, min_samples_leaf=11;, score=0.754 total time=   0.2s
# [CV 5/5] END criterion=entropy, max_depth=10, min_samples_leaf=11;, score=0.754 total time=   0.2s
# [CV 1/5] END criterion=entropy, max_depth=8, min_samples_leaf=11;, score=0.754 total time=   0.2s
# [CV 2/5] END criterion=entropy, max_depth=8, min_samples_leaf=11;, score=0.754 total time=   0.2s
# [CV 3/5] END criterion=entropy, max_depth=8, min_samples_leaf=11;, score=0.755 total time=   0.2s
# [CV 4/5] END criterion=entropy, max_depth=8, min_samples_leaf=11;, score=0.754 total time=   0.2s
# [CV 5/5] END criterion=entropy, max_depth=8, min_samples_leaf=11;, score=0.754 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=5, min_samples_leaf=8;, score=0.754 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=5, min_samples_leaf=8;, score=0.754 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=5, min_samples_leaf=8;, score=0.755 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=5, min_samples_leaf=8;, score=0.754 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=5, min_samples_leaf=8;, score=0.754 total time=   0.2s
# [CV 1/5] END criterion=entropy, max_depth=2, min_samples_leaf=13;, score=0.754 total time=   0.2s
# [CV 2/5] END criterion=entropy, max_depth=2, min_samples_leaf=13;, score=0.754 total time=   0.2s
# [CV 3/5] END criterion=entropy, max_depth=2, min_samples_leaf=13;, score=0.755 total time=   0.2s
# [CV 4/5] END criterion=entropy, max_depth=2, min_samples_leaf=13;, score=0.754 total time=   0.2s
# [CV 5/5] END criterion=entropy, max_depth=2, min_samples_leaf=13;, score=0.754 total time=   0.2s
# [CV 1/5] END criterion=log_loss, max_depth=4, min_samples_leaf=11;, score=0.754 total time=   0.2s
# [CV 2/5] END criterion=log_loss, max_depth=4, min_samples_leaf=11;, score=0.754 total time=   0.2s
# [CV 3/5] END criterion=log_loss, max_depth=4, min_samples_leaf=11;, score=0.755 total time=   0.3s
# [CV 4/5] END criterion=log_loss, max_depth=4, min_samples_leaf=11;, score=0.754 total time=   0.2s
# [CV 5/5] END criterion=log_loss, max_depth=4, min_samples_leaf=11;, score=0.754 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=4, min_samples_leaf=14;, score=0.754 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=4, min_samples_leaf=14;, score=0.754 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=4, min_samples_leaf=14;, score=0.755 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=4, min_samples_leaf=14;, score=0.754 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=4, min_samples_leaf=14;, score=0.754 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=6, min_samples_leaf=7;, score=0.754 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=6, min_samples_leaf=7;, score=0.754 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=6, min_samples_leaf=7;, score=0.755 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=6, min_samples_leaf=7;, score=0.754 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=6, min_samples_leaf=7;, score=0.754 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=6, min_samples_leaf=10;, score=0.754 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=6, min_samples_leaf=10;, score=0.754 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=6, min_samples_leaf=10;, score=0.755 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=6, min_samples_leaf=10;, score=0.754 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=6, min_samples_leaf=10;, score=0.754 total time=   0.2s
# [CV 1/5] END criterion=entropy, max_depth=4, min_samples_leaf=11;, score=0.754 total time=   0.2s
# [CV 2/5] END criterion=entropy, max_depth=4, min_samples_leaf=11;, score=0.754 total time=   0.2s
# [CV 3/5] END criterion=entropy, max_depth=4, min_samples_leaf=11;, score=0.755 total time=   0.2s
# [CV 4/5] END criterion=entropy, max_depth=4, min_samples_leaf=11;, score=0.754 total time=   0.2s
# [CV 5/5] END criterion=entropy, max_depth=4, min_samples_leaf=11;, score=0.754 total time=   0.2s
# [CV 1/5] END criterion=log_loss, max_depth=14, min_samples_leaf=14;, score=0.754 total time=   0.2s
# [CV 2/5] END criterion=log_loss, max_depth=14, min_samples_leaf=14;, score=0.754 total time=   0.2s
# [CV 3/5] END criterion=log_loss, max_depth=14, min_samples_leaf=14;, score=0.755 total time=   0.2s
# [CV 4/5] END criterion=log_loss, max_depth=14, min_samples_leaf=14;, score=0.754 total time=   0.2s
# [CV 5/5] END criterion=log_loss, max_depth=14, min_samples_leaf=14;, score=0.754 total time=   0.3s
# [CV 1/5] END criterion=log_loss, max_depth=3, min_samples_leaf=13;, score=0.754 total time=   0.2s
# [CV 2/5] END criterion=log_loss, max_depth=3, min_samples_leaf=13;, score=0.754 total time=   0.2s
# [CV 3/5] END criterion=log_loss, max_depth=3, min_samples_leaf=13;, score=0.755 total time=   0.2s
# [CV 4/5] END criterion=log_loss, max_depth=3, min_samples_leaf=13;, score=0.754 total time=   0.2s
# [CV 5/5] END criterion=log_loss, max_depth=3, min_samples_leaf=13;, score=0.754 total time=   0.2s
# [CV 1/5] END criterion=entropy, max_depth=6, min_samples_leaf=11;, score=0.754 total time=   0.2s
# [CV 2/5] END criterion=entropy, max_depth=6, min_samples_leaf=11;, score=0.754 total time=   0.2s
# [CV 3/5] END criterion=entropy, max_depth=6, min_samples_leaf=11;, score=0.755 total time=   0.2s
# [CV 4/5] END criterion=entropy, max_depth=6, min_samples_leaf=11;, score=0.754 total time=   0.2s
# [CV 5/5] END criterion=entropy, max_depth=6, min_samples_leaf=11;, score=0.754 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=5, min_samples_leaf=7;, score=0.754 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=5, min_samples_leaf=7;, score=0.754 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=5, min_samples_leaf=7;, score=0.755 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=5, min_samples_leaf=7;, score=0.754 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=5, min_samples_leaf=7;, score=0.754 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=11, min_samples_leaf=9;, score=0.754 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=11, min_samples_leaf=9;, score=0.754 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=11, min_samples_leaf=9;, score=0.755 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=11, min_samples_leaf=9;, score=0.754 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=11, min_samples_leaf=9;, score=0.754 total time=   0.2s
# [CV 1/5] END criterion=log_loss, max_depth=7, min_samples_leaf=13;, score=0.754 total time=   0.2s
# [CV 2/5] END criterion=log_loss, max_depth=7, min_samples_leaf=13;, score=0.754 total time=   0.2s
# [CV 3/5] END criterion=log_loss, max_depth=7, min_samples_leaf=13;, score=0.755 total time=   0.2s
# [CV 4/5] END criterion=log_loss, max_depth=7, min_samples_leaf=13;, score=0.754 total time=   0.2s
# [CV 5/5] END criterion=log_loss, max_depth=7, min_samples_leaf=13;, score=0.754 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=12, min_samples_leaf=6;, score=0.754 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=12, min_samples_leaf=6;, score=0.754 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=12, min_samples_leaf=6;, score=0.755 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=12, min_samples_leaf=6;, score=0.754 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=12, min_samples_leaf=6;, score=0.754 total time=   0.3s
# [CV 1/5] END criterion=log_loss, max_depth=3, min_samples_leaf=9;, score=0.754 total time=   0.2s
# [CV 2/5] END criterion=log_loss, max_depth=3, min_samples_leaf=9;, score=0.754 total time=   0.2s
# [CV 3/5] END criterion=log_loss, max_depth=3, min_samples_leaf=9;, score=0.755 total time=   0.2s
# [CV 4/5] END criterion=log_loss, max_depth=3, min_samples_leaf=9;, score=0.754 total time=   0.2s
# [CV 5/5] END criterion=log_loss, max_depth=3, min_samples_leaf=9;, score=0.754 total time=   0.2s
# [CV 1/5] END criterion=entropy, max_depth=3, min_samples_leaf=13;, score=0.754 total time=   0.2s
# [CV 2/5] END criterion=entropy, max_depth=3, min_samples_leaf=13;, score=0.754 total time=   0.2s
# [CV 3/5] END criterion=entropy, max_depth=3, min_samples_leaf=13;, score=0.755 total time=   0.2s
# [CV 4/5] END criterion=entropy, max_depth=3, min_samples_leaf=13;, score=0.754 total time=   0.2s
# [CV 5/5] END criterion=entropy, max_depth=3, min_samples_leaf=13;, score=0.754 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=13, min_samples_leaf=10;, score=0.754 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=13, min_samples_leaf=10;, score=0.754 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=13, min_samples_leaf=10;, score=0.755 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=13, min_samples_leaf=10;, score=0.754 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=13, min_samples_leaf=10;, score=0.754 total time=   0.2s
# RandomizedSearchCV(estimator=ExtraTreesClassifier(n_estimators=300,
#                                                   random_state=7),
#                    n_iter=50,
#                    param_distributions={'criterion': ['gini', 'entropy',
#                                                       'log_loss'],
#                                         'max_depth': range(2, 15),
#                                         'min_samples_leaf': range(5, 16)},
#                    verbose=4)

# %%
# 모델 파라미터
print(f'[ searchCV.best_score_ ]  {searchCV.best_score_}')
print(f'[ searchCV.best_params_ ] {searchCV.best_params_}')
print(f'[ searchCV.best_estimator_ ]  {searchCV.best_estimator_}')

cv_resultDF= pd.DataFrame(searchCV.cv_results_)
cv_resultDF
# Out:
# [ searchCV.best_score_ ]  0.7567838898349004
# [ searchCV.best_params_ ] {'min_samples_leaf': 5, 'max_depth': 14, 'criterion': 'gini'}
# [ searchCV.best_estimator_ ]  ExtraTreesClassifier(max_depth=14, min_samples_leaf=5, n_estimators=300,
#                      random_state=7)
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0
# 19                     11              14        log_loss
# 20                     12              10        log_loss
# 21                      6              11            gini
# 22                     10               3        log_loss
# 23                      6               9        log_loss
# 24                     10               6        log_loss
# 25                     11               9        log_loss
# 26                     14               5         entropy
# 27                      7              12        log_loss
# 28                     15              13         entropy
# 29                     15               3         entropy
# 30                     14               4        log_loss
# 31                     11              10         entropy
# 32                     11               8         entropy
# 33                      8               5            gini
# 34                     13               2         entropy
# 35                     11               4        log_loss
# 36                     14               4            gini
# 37                      7               6            gini
# 38                     10               6            gini
# 39                     11               4         entropy
# 40                     14              14        log_loss
# 41                     13               3        log_loss
# 42                     11               6         entropy
# 43                      7               5            gini
# 44                      9              11            gini
# 45                     13               7        log_loss
# 46                      6              12            gini
# 47                      9               3        log_loss
# 48                     13               3         entropy
# 49                     10              13            gini
#
#                                                params  split0_test_score  \
# 0   {'min_samples_leaf': 5, 'max_depth': 14, 'crit...           0.753846
# 1   {'min_samples_leaf': 14, 'max_depth': 12, 'cri...           0.753846
# 2   {'min_samples_leaf': 5, 'max_depth': 9, 'crite...           0.753846
# 3   {'min_samples_leaf': 13, 'max_depth': 5, 'crit...           0.753846
# 4   {'min_samples_leaf': 8, 'max_depth': 11, 'crit...           0.753846
# 5   {'min_samples_leaf': 7, 'max_depth': 12, 'crit...           0.753846
# 6   {'min_samples_leaf': 10, 'max_depth': 11, 'cri...           0.753846
# 7   {'min_samples_leaf': 11, 'max_depth': 11, 'cri...           0.753846
# 8   {'min_samples_leaf': 15, 'max_depth': 6, 'crit...           0.753846
# 9   {'min_samples_leaf': 10, 'max_depth': 9, 'crit...           0.753846
# 10  {'min_samples_leaf': 8, 'max_depth': 3, 'crite...           0.753846
# 11  {'min_samples_leaf': 8, 'max_depth': 13, 'crit...           0.753846
# 12  {'min_samples_leaf': 5, 'max_depth': 2, 'crite...           0.753846
# 13  {'min_samples_leaf': 6, 'max_depth': 7, 'crite...           0.753846
# 14  {'min_samples_leaf': 9, 'max_depth': 2, 'crite...           0.753846
# 15  {'min_samples_leaf': 10, 'max_depth': 5, 'crit...           0.753846
# 16  {'min_samples_leaf': 6, 'max_depth': 11, 'crit...           0.753846
# 17  {'min_samples_leaf': 15, 'max_depth': 6, 'crit...           0.753846
# 18  {'min_samples_leaf': 5, 'max_depth': 3, 'crite...           0.753846
# 19  {'min_samples_leaf': 11, 'max_depth': 14, 'cri...           0.753846
# 20  {'min_samples_leaf': 12, 'max_depth': 10, 'cri...           0.753846
# 21  {'min_samples_leaf': 6, 'max_depth': 11, 'crit...           0.753846
# 22  {'min_samples_leaf': 10, 'max_depth': 3, 'crit...           0.753846
# 23  {'min_samples_leaf': 6, 'max_depth': 9, 'crite...           0.753846
# 24  {'min_samples_leaf': 10, 'max_depth': 6, 'crit...           0.753846
# 25  {'min_samples_leaf': 11, 'max_depth': 9, 'crit...           0.753846
# 26  {'min_samples_leaf': 14, 'max_depth': 5, 'crit...           0.753846
# 27  {'min_samples_leaf': 7, 'max_depth': 12, 'crit...           0.753846
# 28  {'min_samples_leaf': 15, 'max_depth': 13, 'cri...           0.753846
# 29  {'min_samples_leaf': 15, 'max_depth': 3, 'crit...           0.753846
# 30  {'min_samples_leaf': 14, 'max_depth': 4, 'crit...           0.753846
# 31  {'min_samples_leaf': 11, 'max_depth': 10, 'cri...           0.753846
# 32  {'min_samples_leaf': 11, 'max_depth': 8, 'crit...           0.753846
# 33  {'min_samples_leaf': 8, 'max_depth': 5, 'crite...           0.753846
# 34  {'min_samples_leaf': 13, 'max_depth': 2, 'crit...           0.753846
# 35  {'min_samples_leaf': 11, 'max_depth': 4, 'crit...           0.753846
# 36  {'min_samples_leaf': 14, 'max_depth': 4, 'crit...           0.753846
# 37  {'min_samples_leaf': 7, 'max_depth': 6, 'crite...           0.753846
# 38  {'min_samples_leaf': 10, 'max_depth': 6, 'crit...           0.753846
# 39  {'min_samples_leaf': 11, 'max_depth': 4, 'crit...           0.753846
# 40  {'min_samples_leaf': 14, 'max_depth': 14, 'cri...           0.753846
# 41  {'min_samples_leaf': 13, 'max_depth': 3, 'crit...           0.753846
# 42  {'min_samples_leaf': 11, 'max_depth': 6, 'crit...           0.753846
# 43  {'min_samples_leaf': 7, 'max_depth': 5, 'crite...           0.753846
# 44  {'min_samples_leaf': 9, 'max_depth': 11, 'crit...           0.753846
# 45  {'min_samples_leaf': 13, 'max_depth': 7, 'crit...           0.753846
# 46  {'min_samples_leaf': 6, 'max_depth': 12, 'crit...           0.753846
# 47  {'min_samples_leaf': 9, 'max_depth': 3, 'crite...           0.753846
# 48  {'min_samples_leaf': 13, 'max_depth': 3, 'crit...           0.753846
# 49  {'min_samples_leaf': 10, 'max_depth': 13, 'cri...           0.753846
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.753846           0.754572           0.753609
# 1            0.753846           0.754572           0.753609
# 2            0.753846           0.754572           0.753609
# 3            0.753846           0.754572           0.753609
# 4            0.753846           0.754572           0.753609
# 5            0.753846           0.754572           0.753609
# 6            0.753846           0.754572           0.753609
# 7            0.753846           0.754572           0.753609
# 8            0.753846           0.754572           0.753609
# 9            0.753846           0.754572           0.753609
# 10           0.753846           0.754572           0.753609
# 11           0.753846           0.754572           0.753609
# 12           0.753846           0.754572           0.753609
# 13           0.753846           0.754572           0.753609
# 14           0.753846           0.754572           0.753609
# 15           0.753846           0.754572           0.753609
# 16           0.753846           0.754572           0.753609
# 17           0.753846           0.754572           0.753609
# 18           0.753846           0.754572           0.753609
# 19           0.753846           0.754572           0.753609
# 20           0.753846           0.754572           0.753609
# 21           0.753846           0.754572           0.753609
# 22           0.753846           0.754572           0.753609
# 23           0.753846           0.754572           0.753609
# 24           0.753846           0.754572           0.753609
# 25           0.753846           0.754572           0.753609
# 26           0.753846           0.754572           0.753609
# 27           0.753846           0.754572           0.753609
# 28           0.753846           0.754572           0.753609
# 29           0.753846           0.754572           0.753609

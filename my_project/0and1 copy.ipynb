# %%
## 모듈 로딩
import os
import cv2
import json
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import imantics
from PIL import Image
from skimage.transform import resize
from sklearn.model_selection import train_test_split
from torchvision.datasets import ImageFolder
import torchvision.transforms as transforms
from torchvision import datasets, transforms
from torch.utils.data import random_split, DataLoader
from torch import optim
from torchmetrics.classification import *
from torch.optim.lr_scheduler import ReduceLROnPlateau
import torch.nn.functional as F
# %matplotlib inline

# %% [markdown]
# 이름 변경

# %% [markdown]
# 0은 충치없음 1은 충치있음

# %%
img_dir = './data/0_and_1'

# %%
preprocessing = transforms.Compose([
transforms.Resize((512,512)),
transforms.ToTensor()])

# %%
imgDS = datasets.ImageFolder(root=img_dir, transform=preprocessing)

# %%
imgDS.class_to_idx
# Out:
# {'0': 0, '1': 1}

# %%
# train, val, test 분할 비율 정의 (예: 70%, 15%, 15%)
train_size = int(0.7 * len(imgDS))
val_size = int(0.15 * len(imgDS))
test_size = len(imgDS) - train_size - val_size

# 데이터 분할
train_data, val_data, test_data = random_split(imgDS, [train_size, val_size, test_size])

# DataLoader 생성 (batch_size는 필요에 따라 설정)
train_loader = DataLoader(train_data, batch_size=32, shuffle=True)
val_loader = DataLoader(val_data, batch_size=32, shuffle=False)
test_loader = DataLoader(test_data, batch_size=32, shuffle=False)

# %%
print(len(train_data),len(val_data),len(test_data))
# Out:
# 140 30 30

# %% [markdown]
# ----

# %%
from torchvision import models
from torchvision.models import VGG16_Weights
from torchinfo import summary

# 사전 학습된 모델 로딩
model = models.vgg16(weights=models.VGG16_Weights.IMAGENET1K_V1)

# %%
summary(model, input_size=[1, 3, 512, 512])
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# VGG                                      [1, 1000]                 --
# ├─Sequential: 1-1                        [1, 512, 16, 16]          --
# │    └─Conv2d: 2-1                       [1, 64, 512, 512]         1,792
# │    └─ReLU: 2-2                         [1, 64, 512, 512]         --
# │    └─Conv2d: 2-3                       [1, 64, 512, 512]         36,928
# │    └─ReLU: 2-4                         [1, 64, 512, 512]         --
# │    └─MaxPool2d: 2-5                    [1, 64, 256, 256]         --
# │    └─Conv2d: 2-6                       [1, 128, 256, 256]        73,856
# │    └─ReLU: 2-7                         [1, 128, 256, 256]        --
# │    └─Conv2d: 2-8                       [1, 128, 256, 256]        147,584
# │    └─ReLU: 2-9                         [1, 128, 256, 256]        --
# │    └─MaxPool2d: 2-10                   [1, 128, 128, 128]        --
# │    └─Conv2d: 2-11                      [1, 256, 128, 128]        295,168
# │    └─ReLU: 2-12                        [1, 256, 128, 128]        --
# │    └─Conv2d: 2-13                      [1, 256, 128, 128]        590,080
# │    └─ReLU: 2-14                        [1, 256, 128, 128]        --
# │    └─Conv2d: 2-15                      [1, 256, 128, 128]        590,080
# │    └─ReLU: 2-16                        [1, 256, 128, 128]        --
# │    └─MaxPool2d: 2-17                   [1, 256, 64, 64]          --
# │    └─Conv2d: 2-18                      [1, 512, 64, 64]          1,180,160
# │    └─ReLU: 2-19                        [1, 512, 64, 64]          --
# │    └─Conv2d: 2-20                      [1, 512, 64, 64]          2,359,808
# │    └─ReLU: 2-21                        [1, 512, 64, 64]          --
# │    └─Conv2d: 2-22                      [1, 512, 64, 64]          2,359,808
# │    └─ReLU: 2-23                        [1, 512, 64, 64]          --
# │    └─MaxPool2d: 2-24                   [1, 512, 32, 32]          --
# │    └─Conv2d: 2-25                      [1, 512, 32, 32]          2,359,808
# │    └─ReLU: 2-26                        [1, 512, 32, 32]          --
# │    └─Conv2d: 2-27                      [1, 512, 32, 32]          2,359,808
# │    └─ReLU: 2-28                        [1, 512, 32, 32]          --
# │    └─Conv2d: 2-29                      [1, 512, 32, 32]          2,359,808
# │    └─ReLU: 2-30                        [1, 512, 32, 32]          --
# │    └─MaxPool2d: 2-31                   [1, 512, 16, 16]          --
# ├─AdaptiveAvgPool2d: 1-2                 [1, 512, 7, 7]            --
# ├─Sequential: 1-3                        [1, 1000]                 --
# │    └─Linear: 2-32                      [1, 4096]                 102,764,544
# │    └─ReLU: 2-33                        [1, 4096]                 --
# │    └─Dropout: 2-34                     [1, 4096]                 --
# │    └─Linear: 2-35                      [1, 4096]                 16,781,312
# │    └─ReLU: 2-36                        [1, 4096]                 --
# │    └─Dropout: 2-37                     [1, 4096]                 --
# │    └─Linear: 2-38                      [1, 1000]                 4,097,000
# ==========================================================================================
# Total params: 138,357,544
# Trainable params: 138,357,544
# Non-trainable params: 0
# Total mult-adds (G): 80.37
# ==========================================================================================
# Input size (MB): 3.15
# Forward/backward pass size (MB): 566.30
# Params size (MB): 553.43
# Estimated Total Size (MB): 1122.88
# ==========================================================================================

# %%
class CustomVgg16Model(nn.Module):
    def __init__(self):
        super(CustomVgg16Model, self).__init__()    
        self.features = model.features
        self.avgpool = model.avgpool
        self.classifier = model.classifier
        self.custom_layer = nn.Sequential(
            nn.ReLU(),
            nn.Linear(1000, 500),
            nn.ReLU(),
            nn.Linear(500, 50),
            nn.ReLU(),
            nn.Linear(50, 1)
        )
    
    def forward(self, x):
        y = self.features(x)
        y = self.avgpool(y)
        y = torch.flatten(y, 1)
        y = self.classifier(y)
        y = F.sigmoid(self.custom_layer(y))
        
        return y

# %%
model = CustomVgg16Model()
print(model)
summary(model)
# Out:
# CustomVgg16Model(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace=True)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace=True)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace=True)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace=True)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace=True)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace=True)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=4096, out_features=1000, bias=True)
#   )
#   (custom_layer): Sequential(
#     (0): ReLU()
#     (1): Linear(in_features=1000, out_features=500, bias=True)
#     (2): ReLU()
#     (3): Linear(in_features=500, out_features=50, bias=True)
#     (4): ReLU()
#     (5): Linear(in_features=50, out_features=1, bias=True)
#   )
# )
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# CustomVgg16Model                         --
# ├─Sequential: 1-1                        --
# │    └─Conv2d: 2-1                       1,792
# │    └─ReLU: 2-2                         --
# │    └─Conv2d: 2-3                       36,928
# │    └─ReLU: 2-4                         --
# │    └─MaxPool2d: 2-5                    --
# │    └─Conv2d: 2-6                       73,856
# │    └─ReLU: 2-7                         --
# │    └─Conv2d: 2-8                       147,584
# │    └─ReLU: 2-9                         --
# │    └─MaxPool2d: 2-10                   --
# │    └─Conv2d: 2-11                      295,168
# │    └─ReLU: 2-12                        --
# │    └─Conv2d: 2-13                      590,080
# │    └─ReLU: 2-14                        --
# │    └─Conv2d: 2-15                      590,080
# │    └─ReLU: 2-16                        --
# │    └─MaxPool2d: 2-17                   --
# │    └─Conv2d: 2-18                      1,180,160
# │    └─ReLU: 2-19                        --
# │    └─Conv2d: 2-20                      2,359,808
# │    └─ReLU: 2-21                        --
# │    └─Conv2d: 2-22                      2,359,808
# │    └─ReLU: 2-23                        --
# │    └─MaxPool2d: 2-24                   --
# │    └─Conv2d: 2-25                      2,359,808
# │    └─ReLU: 2-26                        --
# │    └─Conv2d: 2-27                      2,359,808
# │    └─ReLU: 2-28                        --
# │    └─Conv2d: 2-29                      2,359,808
# │    └─ReLU: 2-30                        --
# │    └─MaxPool2d: 2-31                   --
# ├─AdaptiveAvgPool2d: 1-2                 --
# ├─Sequential: 1-3                        --
# │    └─Linear: 2-32                      102,764,544
# │    └─ReLU: 2-33                        --
# │    └─Dropout: 2-34                     --
# │    └─Linear: 2-35                      16,781,312
# │    └─ReLU: 2-36                        --
# │    └─Dropout: 2-37                     --
# │    └─Linear: 2-38                      4,097,000
# ├─Sequential: 1-4                        --
# │    └─ReLU: 2-39                        --
# │    └─Linear: 2-40                      500,500
# │    └─ReLU: 2-41                        --
# │    └─Linear: 2-42                      25,050
# │    └─ReLU: 2-43                        --
# │    └─Linear: 2-44                      51
# =================================================================
# Total params: 138,883,145
# Trainable params: 138,883,145
# Non-trainable params: 0
# =================================================================

# %%
# 사전학습된 모델의 파라미터 비활성화 설정
for named, params in model.named_parameters():
    print(f"[{named}] - {params.shape}")
    # 역전파시 업데이트가 되지 않도록 설정
    params.requires_grad = False
# Out:
# [features.0.weight] - torch.Size([64, 3, 3, 3])
# [features.0.bias] - torch.Size([64])
# [features.2.weight] - torch.Size([64, 64, 3, 3])
# [features.2.bias] - torch.Size([64])
# [features.5.weight] - torch.Size([128, 64, 3, 3])
# [features.5.bias] - torch.Size([128])
# [features.7.weight] - torch.Size([128, 128, 3, 3])
# [features.7.bias] - torch.Size([128])
# [features.10.weight] - torch.Size([256, 128, 3, 3])
# [features.10.bias] - torch.Size([256])
# [features.12.weight] - torch.Size([256, 256, 3, 3])
# [features.12.bias] - torch.Size([256])
# [features.14.weight] - torch.Size([256, 256, 3, 3])
# [features.14.bias] - torch.Size([256])
# [features.17.weight] - torch.Size([512, 256, 3, 3])
# [features.17.bias] - torch.Size([512])
# [features.19.weight] - torch.Size([512, 512, 3, 3])
# [features.19.bias] - torch.Size([512])
# [features.21.weight] - torch.Size([512, 512, 3, 3])
# [features.21.bias] - torch.Size([512])
# [features.24.weight] - torch.Size([512, 512, 3, 3])
# [features.24.bias] - torch.Size([512])
# [features.26.weight] - torch.Size([512, 512, 3, 3])
# [features.26.bias] - torch.Size([512])
# [features.28.weight] - torch.Size([512, 512, 3, 3])
# [features.28.bias] - torch.Size([512])
# [classifier.0.weight] - torch.Size([4096, 25088])
# [classifier.0.bias] - torch.Size([4096])
# [classifier.3.weight] - torch.Size([4096, 4096])
# [classifier.3.bias] - torch.Size([4096])
# [classifier.6.weight] - torch.Size([1000, 4096])
# [classifier.6.bias] - torch.Size([1000])
# [custom_layer.1.weight] - torch.Size([500, 1000])
# [custom_layer.1.bias] - torch.Size([500])
# [custom_layer.3.weight] - torch.Size([50, 500])
# [custom_layer.3.bias] - torch.Size([50])
# [custom_layer.5.weight] - torch.Size([1, 50])
# [custom_layer.5.bias] - torch.Size([1])

# %%
# 모델의 FC 파라미터 활성화 설정
for named, params in model.custom_layer.named_parameters():
    print(f"[{named}] - {params.shape}")
    params.requires_grad = True
# Out:
# [1.weight] - torch.Size([500, 1000])
# [1.bias] - torch.Size([500])
# [3.weight] - torch.Size([50, 500])
# [3.bias] - torch.Size([50])
# [5.weight] - torch.Size([1, 50])
# [5.bias] - torch.Size([1])

# %%
## 학습 진행 관련 설정
device = torch.device('cuda' if torch.cuda.is_available() else "cpu")
epochs = 100
BATCH_SIZE = 8
DEVICE = 'cuda' if torch.cuda.is_available() else 'cpu'
LR = 0.001
optimizer = optim.Adam(model.parameters(), lr=LR)
crossLoss = nn.BCELoss()
scheduler = ReduceLROnPlateau(optimizer, patience=10, mode='max')
criterion = nn.BCEWithLogitsLoss().to(device)
train_batch_cnt = len(train_loader) / BATCH_SIZE
val_batch_cnt = len(val_loader) / BATCH_SIZE

# %%
def train(model, dataset, criterion, optimizer, device, interval, epoch):
    model.train()
    losses= list()
    corrects = list()
    best_loss = 0
    best_score = 0

    for images, labels in dataset:
        images, labels = images.to(device), labels.to(device).float().unsqueeze(1)
   
        pre_y = model(images)
    
        loss = criterion(pre_y, labels)
        losses.append(loss.item())

        yhat = torch.sigmoid(pre_y)>.5
        corrects.extend(torch.eq(yhat, labels).cpu().tolist())

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        if epochs % interval ==0:
            print(epoch)
            print(f'Train Loss : {np.mean(losses)}, Train Accuracy : {np.mean(corrects)}')
            if best_loss == 0:
                best_loss == np.mean(losses)
            elif best_loss < np.mean(losses):
                best_loss == np.mean(losses)

            if best_score < np.mean(corrects):
                best_score = np.mean(corrects)
            
        print(f'T_best_Loss : {best_loss}, T_best_score : {best_score}')

# %%
def Val(model, dataset, criterion, device):
    model.eval()
    losses_V= list()
    corrects_V = list()

    for images, labels in dataset:
        images, labels = images.to(device), labels.to(device).float().unsqueeze(1)
        pre_v = model(images)
        loss = criterion(pre_v, labels)
        losses_V.append(loss.item())
        
        yhat = torch.sigmoid(pre_v)>.5
        corrects_V.extend(torch.eq(yhat, labels).cpu().tolist())
        
    print(f'Val Loss : {np.mean(losses_V)}, Val Accuracy : {np.mean(corrects_V)}''\n\n')

    return max(corrects_V)
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
interval = 10
BEST_HISTORY = 0

for epoch in range(epochs):
    train(model, train_loader, criterion, optimizer, device, interval, epoch)
    score = Val(model, val_loader, criterion, device)

    # 모델 폴더가 없다면 생성
    if not os.path.exists('./model/'):
        os.mkdir('./model/')

    if BEST_HISTORY < max(score):
        BEST_HISTORY = max(score)
        torch.save(model,f'./model/best_model{epoch}.pth')
        
    if scheduler.num_bad_epochs >= scheduler.patience:
        print('성능 및 손실의 개선이 없어서 학습을 중단합니다.\n')
        break
# Out:
# {0.0}
# Train Loss : 0.7555952072143555, Train Accuracy : 0.4375
# T_best_Loss : 0, T_best_score : 0.4375
# {0.0}
# Train Loss : 0.6954076886177063, Train Accuracy : 0.546875
# T_best_Loss : 0, T_best_score : 0.546875
# {0.0}
# Train Loss : 0.7020604014396667, Train Accuracy : 0.4895833333333333
# T_best_Loss : 0, T_best_score : 0.546875
# {0.0}
# Train Loss : 0.6860512346029282, Train Accuracy : 0.5
# T_best_Loss : 0, T_best_score : 0.546875
# {0.0}
# Train Loss : 0.6763876795768737, Train Accuracy : 0.4928571428571429
# T_best_Loss : 0, T_best_score : 0.546875
# Val Loss : 0.5673774480819702, Val Accuracy : 0.6
# {0.1}
# Train Loss : 0.6289001703262329, Train Accuracy : 0.40625
# T_best_Loss : 0, T_best_score : 0.40625
# {0.1}
# Train Loss : 0.6023958325386047, Train Accuracy : 0.46875
# T_best_Loss : 0, T_best_score : 0.46875
# {0.1}
# Train Loss : 0.5751719872156779, Train Accuracy : 0.5
# T_best_Loss : 0, T_best_score : 0.5
# {0.1}
# Train Loss : 0.5669778287410736, Train Accuracy : 0.5078125
# T_best_Loss : 0, T_best_score : 0.5078125
# {0.1}
# Train Loss : 0.5799933671951294, Train Accuracy : 0.4928571428571429
# T_best_Loss : 0, T_best_score : 0.5078125
# Val Loss : 0.48134374618530273, Val Accuracy : 0.6
# {0.2}
# Train Loss : 0.5198287963867188, Train Accuracy : 0.5
# T_best_Loss : 0, T_best_score : 0.5
# {0.2}
# Train Loss : 0.5034916698932648, Train Accuracy : 0.546875
# T_best_Loss : 0, T_best_score : 0.546875
# {0.2}
# Train Loss : 0.5210345188776652, Train Accuracy : 0.5104166666666666
# T_best_Loss : 0, T_best_score : 0.546875
# {0.2}
# Train Loss : 0.5274153053760529, Train Accuracy : 0.484375
# T_best_Loss : 0, T_best_score : 0.546875
# {0.2}
# Train Loss : 0.5168126106262207, Train Accuracy : 0.4928571428571429
# T_best_Loss : 0, T_best_score : 0.546875
# Val Loss : 0.4688594937324524, Val Accuracy : 0.6
# {0.3}
# Train Loss : 0.518665075302124, Train Accuracy : 0.46875
# T_best_Loss : 0, T_best_score : 0.46875
# {0.3}
# Train Loss : 0.5050778239965439, Train Accuracy : 0.53125
# T_best_Loss : 0, T_best_score : 0.53125
# {0.3}
# Train Loss : 0.5299665629863739, Train Accuracy : 0.4583333333333333
# T_best_Loss : 0, T_best_score : 0.53125
# {0.3}
# Train Loss : 0.5179257690906525, Train Accuracy : 0.484375
# T_best_Loss : 0, T_best_score : 0.53125
# {0.3}
# Train Loss : 0.508993124961853, Train Accuracy : 0.4928571428571429
# T_best_Loss : 0, T_best_score : 0.53125
# Val Loss : 0.46582481265068054, Val Accuracy : 0.6
# {0.4}
# Train Loss : 0.5195131897926331, Train Accuracy : 0.46875
# T_best_Loss : 0, T_best_score : 0.46875
# {0.4}
# Train Loss : 0.5017886757850647, Train Accuracy : 0.515625
# T_best_Loss : 0, T_best_score : 0.515625
# {0.4}
# Train Loss : 0.5030656456947327, Train Accuracy : 0.5104166666666666
# T_best_Loss : 0, T_best_score : 0.515625
# {0.4}
# Train Loss : 0.5130677372217178, Train Accuracy : 0.4921875
# T_best_Loss : 0, T_best_score : 0.515625
# {0.4}
# Train Loss : 0.5111248970031739, Train Accuracy : 0.4928571428571429
# T_best_Loss : 0, T_best_score : 0.515625
# Val Loss : 0.4654275178909302, Val Accuracy : 0.6
# {0.5}
# Train Loss : 0.5595688819885254, Train Accuracy : 0.375
# T_best_Loss : 0, T_best_score : 0.375
# {0.5}
# Train Loss : 0.5462142527103424, Train Accuracy : 0.40625
# T_best_Loss : 0, T_best_score : 0.40625
# {0.5}
# Train Loss : 0.5278767347335815, Train Accuracy : 0.4583333333333333
# T_best_Loss : 0, T_best_score : 0.4583333333333333
# {0.5}
# Train Loss : 0.5101184397935867, Train Accuracy : 0.5078125
# T_best_Loss : 0, T_best_score : 0.5078125
# {0.5}
# Train Loss : 0.5157814979553222, Train Accuracy : 0.5
# T_best_Loss : 0, T_best_score : 0.5078125
# Val Loss : 0.46544530987739563, Val Accuracy : 0.6
# {0.6}
# Train Loss : 0.5363333225250244, Train Accuracy : 0.5
# T_best_Loss : 0, T_best_score : 0.5
# {0.6}
# Train Loss : 0.5082437694072723, Train Accuracy : 0.546875
# T_best_Loss : 0, T_best_score : 0.546875
# {0.6}
# Train Loss : 0.5067940155665079, Train Accuracy : 0.53125
# T_best_Loss : 0, T_best_score : 0.546875
# {0.6}
# Train Loss : 0.511844664812088, Train Accuracy : 0.515625
# T_best_Loss : 0, T_best_score : 0.546875
# {0.6}
# Train Loss : 0.5037877023220062, Train Accuracy : 0.5214285714285715
# T_best_Loss : 0, T_best_score : 0.546875
# Val Loss : 0.46526339650154114, Val Accuracy : 0.6
# {0.7}
# Train Loss : 0.5152468085289001, Train Accuracy : 0.53125
# T_best_Loss : 0, T_best_score : 0.53125
# {0.7}
# Train Loss : 0.5045600086450577, Train Accuracy : 0.578125
# T_best_Loss : 0, T_best_score : 0.578125
# {0.7}
# Train Loss : 0.5052695969740549, Train Accuracy : 0.5520833333333334
# T_best_Loss : 0, T_best_score : 0.578125
# {0.7}
# Train Loss : 0.509680949151516, Train Accuracy : 0.5390625
# T_best_Loss : 0, T_best_score : 0.578125
# {0.7}
# Train Loss : 0.5083963215351105, Train Accuracy : 0.5428571428571428
# T_best_Loss : 0, T_best_score : 0.578125
# Val Loss : 0.4652479588985443, Val Accuracy : 0.6
# {0.8}
# Train Loss : 0.5190210938453674, Train Accuracy : 0.5625
# T_best_Loss : 0, T_best_score : 0.5625
# {0.8}
# Train Loss : 0.5290736556053162, Train Accuracy : 0.546875
# T_best_Loss : 0, T_best_score : 0.5625
# {0.8}
# Train Loss : 0.5237741072972616, Train Accuracy : 0.5625
# T_best_Loss : 0, T_best_score : 0.5625
# {0.8}
# Train Loss : 0.5216951668262482, Train Accuracy : 0.5546875
# T_best_Loss : 0, T_best_score : 0.5625
# {0.8}
# Train Loss : 0.4926727533340454, Train Accuracy : 0.5857142857142857
# T_best_Loss : 0, T_best_score : 0.5857142857142857
# Val Loss : 0.4652501046657562, Val Accuracy : 0.6
# {0.9}
# Train Loss : 0.47101151943206787, Train Accuracy : 0.65625
# T_best_Loss : 0, T_best_score : 0.65625
# {0.9}
# Train Loss : 0.49325600266456604, Train Accuracy : 0.625
# T_best_Loss : 0, T_best_score : 0.65625
# {0.9}
# Train Loss : 0.4886912902196248, Train Accuracy : 0.625
# T_best_Loss : 0, T_best_score : 0.65625
# {0.9}
# Train Loss : 0.5104637891054153, Train Accuracy : 0.5546875
# T_best_Loss : 0, T_best_score : 0.65625
# {0.9}
# Train Loss : 0.5061318039894104, Train Accuracy : 0.5642857142857143
# T_best_Loss : 0, T_best_score : 0.65625
# Val Loss : 0.4652431607246399, Val Accuracy : 0.6
# {1.0}
# Train Loss : 0.5046730041503906, Train Accuracy : 0.5
# T_best_Loss : 0, T_best_score : 0.5
# {1.0}
# Train Loss : 0.5114099085330963, Train Accuracy : 0.5
# T_best_Loss : 0, T_best_score : 0.5
# {1.0}
# Train Loss : 0.5009176929791769, Train Accuracy : 0.5416666666666666
# T_best_Loss : 0, T_best_score : 0.5416666666666666
# {1.0}
# Train Loss : 0.5124378651380539, Train Accuracy : 0.53125
# T_best_Loss : 0, T_best_score : 0.5416666666666666
# {1.0}
# Train Loss : 0.5243536829948425, Train Accuracy : 0.5214285714285715
# T_best_Loss : 0, T_best_score : 0.5416666666666666
# Val Loss : 0.46525058150291443, Val Accuracy : 0.6
# {1.1}
# Train Loss : 0.4799793064594269, Train Accuracy : 0.59375
# T_best_Loss : 0, T_best_score : 0.59375
# {1.1}
# Train Loss : 0.5068003386259079, Train Accuracy : 0.5625
# T_best_Loss : 0, T_best_score : 0.59375
# {1.1}
# Train Loss : 0.5016538202762604, Train Accuracy : 0.5729166666666666
# T_best_Loss : 0, T_best_score : 0.59375
# {1.1}
# Train Loss : 0.5029404982924461, Train Accuracy : 0.5703125
# T_best_Loss : 0, T_best_score : 0.59375
# {1.1}
# Train Loss : 0.5157348215579987, Train Accuracy : 0.5642857142857143
# T_best_Loss : 0, T_best_score : 0.59375
# Val Loss : 0.4653755724430084, Val Accuracy : 0.7666666666666667
# {1.2}
# Train Loss : 0.515372633934021, Train Accuracy : 0.65625
# T_best_Loss : 0, T_best_score : 0.65625
# {1.2}
# Train Loss : 0.5095760822296143, Train Accuracy : 0.703125
# T_best_Loss : 0, T_best_score : 0.703125
# {1.2}
# Train Loss : 0.5114386876424154, Train Accuracy : 0.7083333333333334
# T_best_Loss : 0, T_best_score : 0.7083333333333334
# {1.2}
# Train Loss : 0.5094295144081116, Train Accuracy : 0.734375
# T_best_Loss : 0, T_best_score : 0.734375
# {1.2}
# Train Loss : 0.5055846393108367, Train Accuracy : 0.7428571428571429
# T_best_Loss : 0, T_best_score : 0.7428571428571429
# Val Loss : 0.46552515029907227, Val Accuracy : 0.7666666666666667
# {1.3}
# Train Loss : 0.550696611404419, Train Accuracy : 0.75
# T_best_Loss : 0, T_best_score : 0.75
# {1.3}
# Train Loss : 0.5210521221160889, Train Accuracy : 0.765625
# T_best_Loss : 0, T_best_score : 0.765625
# {1.3}
# Train Loss : 0.5198579430580139, Train Accuracy : 0.7291666666666666
# T_best_Loss : 0, T_best_score : 0.765625
# {1.3}
# Train Loss : 0.5066887587308884, Train Accuracy : 0.7265625
# T_best_Loss : 0, T_best_score : 0.765625
# {1.3}
# Train Loss : 0.5123238921165466, Train Accuracy : 0.7071428571428572
# T_best_Loss : 0, T_best_score : 0.765625
# Val Loss : 0.46522533893585205, Val Accuracy : 0.6
# {1.4}
# Train Loss : 0.46946683526039124, Train Accuracy : 0.625
# T_best_Loss : 0, T_best_score : 0.625
# {1.4}
# Train Loss : 0.48998863995075226, Train Accuracy : 0.625
# T_best_Loss : 0, T_best_score : 0.625
# {1.4}
# Train Loss : 0.5121533771355947, Train Accuracy : 0.5416666666666666
# T_best_Loss : 0, T_best_score : 0.625
# {1.4}
# Train Loss : 0.5131112560629845, Train Accuracy : 0.53125
# T_best_Loss : 0, T_best_score : 0.625
# {1.4}
# Train Loss : 0.5116518318653107, Train Accuracy : 0.5357142857142857
# T_best_Loss : 0, T_best_score : 0.625
# Val Loss : 0.4652232527732849, Val Accuracy : 0.6
# {1.5}
# Train Loss : 0.5191771984100342, Train Accuracy : 0.5
# T_best_Loss : 0, T_best_score : 0.5
# {1.5}
# Train Loss : 0.49338603019714355, Train Accuracy : 0.59375
# T_best_Loss : 0, T_best_score : 0.59375
# {1.5}
# Train Loss : 0.5086987614631653, Train Accuracy : 0.6041666666666666
# T_best_Loss : 0, T_best_score : 0.6041666666666666
# {1.5}
# Train Loss : 0.5014024525880814, Train Accuracy : 0.65625
# T_best_Loss : 0, T_best_score : 0.65625
# {1.5}
# Train Loss : 0.514430844783783, Train Accuracy : 0.65
# T_best_Loss : 0, T_best_score : 0.65625
# Val Loss : 0.4662083685398102, Val Accuracy : 0.9
# {1.6}
# Train Loss : 0.4794932007789612, Train Accuracy : 0.96875
# T_best_Loss : 0, T_best_score : 0.96875
# {1.6}
# Train Loss : 0.4926745593547821, Train Accuracy : 0.859375
# T_best_Loss : 0, T_best_score : 0.96875
# {1.6}
# Train Loss : 0.5053881208101908, Train Accuracy : 0.8541666666666666
# T_best_Loss : 0, T_best_score : 0.96875
# {1.6}
# Train Loss : 0.5164055377244949, Train Accuracy : 0.8515625
# T_best_Loss : 0, T_best_score : 0.96875
# {1.6}
# Train Loss : 0.501349002122879, Train Accuracy : 0.8571428571428571
# T_best_Loss : 0, T_best_score : 0.96875
# Val Loss : 0.4656083285808563, Val Accuracy : 0.8666666666666667
# {1.7}
# Train Loss : 0.5269534587860107, Train Accuracy : 0.71875
# T_best_Loss : 0, T_best_score : 0.71875
# {1.7}
# Train Loss : 0.5097273141145706, Train Accuracy : 0.71875
# T_best_Loss : 0, T_best_score : 0.71875
# {1.7}
# Train Loss : 0.5075536469618479, Train Accuracy : 0.7395833333333334
# T_best_Loss : 0, T_best_score : 0.7395833333333334
# {1.7}
# Train Loss : 0.5059655234217644, Train Accuracy : 0.734375
# T_best_Loss : 0, T_best_score : 0.7395833333333334
# {1.7}
# Train Loss : 0.5117450892925263, Train Accuracy : 0.7214285714285714
# T_best_Loss : 0, T_best_score : 0.7395833333333334
# Val Loss : 0.46522483229637146, Val Accuracy : 0.7333333333333333
# {1.8}
# Train Loss : 0.5272379517555237, Train Accuracy : 0.59375
# T_best_Loss : 0, T_best_score : 0.59375
# {1.8}
# Train Loss : 0.5271768867969513, Train Accuracy : 0.5625
# T_best_Loss : 0, T_best_score : 0.59375
# {1.8}
# Train Loss : 0.5272667010625204, Train Accuracy : 0.5520833333333334
# T_best_Loss : 0, T_best_score : 0.59375
# {1.8}
# Train Loss : 0.5110926181077957, Train Accuracy : 0.578125
# T_best_Loss : 0, T_best_score : 0.59375
# {1.8}
# Train Loss : 0.5063315451145172, Train Accuracy : 0.5785714285714286
# T_best_Loss : 0, T_best_score : 0.59375
# Val Loss : 0.465225487947464, Val Accuracy : 0.7333333333333333
# {1.9}
# Train Loss : 0.5270337462425232, Train Accuracy : 0.5625
# T_best_Loss : 0, T_best_score : 0.5625
# {1.9}
# Train Loss : 0.5094359219074249, Train Accuracy : 0.65625
# T_best_Loss : 0, T_best_score : 0.65625
# {1.9}
# Train Loss : 0.513646125793457, Train Accuracy : 0.7083333333333334
# T_best_Loss : 0, T_best_score : 0.7083333333333334
# {1.9}
# Train Loss : 0.5080868005752563, Train Accuracy : 0.75
# T_best_Loss : 0, T_best_score : 0.75
# {1.9}
# Train Loss : 0.5197749972343445, Train Accuracy : 0.75
# T_best_Loss : 0, T_best_score : 0.75
# Val Loss : 0.46666377782821655, Val Accuracy : 0.9
# {2.0}
# Train Loss : 0.5255064368247986, Train Accuracy : 0.96875
# T_best_Loss : 0, T_best_score : 0.96875
# {2.0}
# Train Loss : 0.5236329436302185, Train Accuracy : 0.90625
# T_best_Loss : 0, T_best_score : 0.96875
# {2.0}
# Train Loss : 0.4970613718032837, Train Accuracy : 0.8958333333333334
# T_best_Loss : 0, T_best_score : 0.96875
# {2.0}
# Train Loss : 0.505760908126831, Train Accuracy : 0.875
# T_best_Loss : 0, T_best_score : 0.96875
# {2.0}
# Train Loss : 0.5242467999458313, Train Accuracy : 0.8571428571428571
# T_best_Loss : 0, T_best_score : 0.96875
# Val Loss : 0.4652409851551056, Val Accuracy : 0.7666666666666667
# {2.1}
# Train Loss : 0.5154387950897217, Train Accuracy : 0.6875
# T_best_Loss : 0, T_best_score : 0.6875
# {2.1}
# Train Loss : 0.5183490216732025, Train Accuracy : 0.65625
# T_best_Loss : 0, T_best_score : 0.6875
# {2.1}
# Train Loss : 0.5088554620742798, Train Accuracy : 0.6666666666666666
# T_best_Loss : 0, T_best_score : 0.6875
# {2.1}
# Train Loss : 0.5015141740441322, Train Accuracy : 0.6953125
# T_best_Loss : 0, T_best_score : 0.6953125
# {2.1}
# Train Loss : 0.5208465874195098, Train Accuracy : 0.6928571428571428
# T_best_Loss : 0, T_best_score : 0.6953125
# Val Loss : 0.46522289514541626, Val Accuracy : 0.6666666666666666
# {2.2}
# Train Loss : 0.4913351833820343, Train Accuracy : 0.75
# T_best_Loss : 0, T_best_score : 0.75
# {2.2}
# Train Loss : 0.5091857761144638, Train Accuracy : 0.6875
# T_best_Loss : 0, T_best_score : 0.75
# {2.2}
# Train Loss : 0.5269988477230072, Train Accuracy : 0.625
# T_best_Loss : 0, T_best_score : 0.75
# {2.2}
# Train Loss : 0.512160062789917, Train Accuracy : 0.65625
# T_best_Loss : 0, T_best_score : 0.75
# {2.2}
# Train Loss : 0.4977124035358429, Train Accuracy : 0.6571428571428571
# T_best_Loss : 0, T_best_score : 0.75
# Val Loss : 0.4652210474014282, Val Accuracy : 0.6666666666666666
# {2.3}
# Train Loss : 0.5150895118713379, Train Accuracy : 0.6875
# T_best_Loss : 0, T_best_score : 0.6875
# {2.3}
# Train Loss : 0.503643348813057, Train Accuracy : 0.65625
# T_best_Loss : 0, T_best_score : 0.6875
# {2.3}
# Train Loss : 0.5114129881064097, Train Accuracy : 0.6354166666666666
# T_best_Loss : 0, T_best_score : 0.6875
# {2.3}
# Train Loss : 0.5067003443837166, Train Accuracy : 0.65625
# T_best_Loss : 0, T_best_score : 0.6875
# {2.3}
# Train Loss : 0.5060040533542634, Train Accuracy : 0.6571428571428571
# T_best_Loss : 0, T_best_score : 0.6875
# Val Loss : 0.46522122621536255, Val Accuracy : 0.6666666666666666
# {2.4}
# Train Loss : 0.45575371384620667, Train Accuracy : 0.65625
# T_best_Loss : 0, T_best_score : 0.65625
# {2.4}
# Train Loss : 0.4855450242757797, Train Accuracy : 0.625
# T_best_Loss : 0, T_best_score : 0.65625
# {2.4}
# Train Loss : 0.49541879693667096, Train Accuracy : 0.6354166666666666
# T_best_Loss : 0, T_best_score : 0.65625
# {2.4}
# Train Loss : 0.509286679327488, Train Accuracy : 0.6015625
# T_best_Loss : 0, T_best_score : 0.65625
# {2.4}
# Train Loss : 0.5017393231391907, Train Accuracy : 0.6071428571428571
# T_best_Loss : 0, T_best_score : 0.65625
# Val Loss : 0.46522256731987, Val Accuracy : 0.6666666666666666
# {2.5}
# Train Loss : 0.5388271808624268, Train Accuracy : 0.59375
# T_best_Loss : 0, T_best_score : 0.59375
# {2.5}
# Train Loss : 0.5261114835739136, Train Accuracy : 0.625
# T_best_Loss : 0, T_best_score : 0.625
# {2.5}
# Train Loss : 0.526416003704071, Train Accuracy : 0.59375
# T_best_Loss : 0, T_best_score : 0.625
# {2.5}
# Train Loss : 0.5117102041840553, Train Accuracy : 0.609375
# T_best_Loss : 0, T_best_score : 0.625
# {2.5}
# Train Loss : 0.5037361264228821, Train Accuracy : 0.6214285714285714
# T_best_Loss : 0, T_best_score : 0.625
# Val Loss : 0.4652215838432312, Val Accuracy : 0.6666666666666666
# {2.6}
# Train Loss : 0.5389636158943176, Train Accuracy : 0.59375
# T_best_Loss : 0, T_best_score : 0.59375

# %%
def Test(model, dataset, criterion, device):
    model.eval()
    losses_t= list()
    corrects_t = list()

    for images, labels in dataset:
        images, labels = images.to(device), labels.to(device).float().unsqueeze(1)

        pre_t = model(images)
        loss = criterion(pre_t, labels)
        losses_t.append(loss.item())
        
        yhat = torch.sigmoid(pre_t)>.5
        corrects_t.extend(torch.eq(yhat, labels).cpu().tolist())
        
    print(f'Val Loss : {np.mean(losses_t)}, Val Accuracy : {np.mean(corrects_t)}')

    return  print(max(corrects_t))

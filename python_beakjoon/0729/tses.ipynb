# %%
max= [0]*4
max
# Out:
# [0, 0, 0, 0]

# %%
import csv
import matplotlib.pyplot as plt
import platform
import koreanize_matplotlib
import pandas as pd

# %%
data=pd.read_csv('subwaytime.csv')

data
# Out:
#         사용월  호선명     역ID      지하철역 04:00:00~04:59:59 Unnamed: 5  \
# 0       NaN  NaN     NaN       NaN                승차         하차
# 1    Jun.24  1호선   150.0       서울역              654         20
# 2    Jun.24  1호선   151.0        시청               74          0
# 3    Jun.24  1호선   152.0        종각              132          7
# 4    Jun.24  1호선   153.0      종로3가              206         13
# ..      ...  ...     ...       ...               ...        ...
# 618  Jun.24  신림선  4407.0        당곡                1          0
# 619  Jun.24  신림선  4408.0        신림                0          0
# 620  Jun.24  신림선  4409.0        서원                3          1
# 621  Jun.24  신림선  4410.0   서울대벤처타운               26          0
# 622  Jun.24  신림선  4411.0  관악산(서울대)                9          2
#
#     05:00:00~05:59:59 Unnamed: 7 06:00:00~06:59:59 Unnamed: 9  ...  \
# 0                  승차         하차                승차         하차  ...
# 1               8727       9083             13812      56637   ...
# ...
